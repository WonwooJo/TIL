# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import minmax_scale
from scipy.stats import zscore
from sklearn.preprocessing import StandardScaler, RobustScaler
from sklearn.preprocessing import binarize
from sklearn.preprocessing import Binarizer
import matplotlib.pyplot as plt

from datetime import datetime

# %%
# 한글깨짐방지코드
import matplotlib
from matplotlib import font_manager, rc
import platform
if platform.system()=="Windows":
    font_name=font_manager.FontProperties(fname="c:/Windows/Fonts/malgun.ttf").get_name()
    rc('font', family=font_name)
matplotlib.rcParams['axes.unicode_minus']=False

import warnings
warnings.filterwarnings("ignore")

# 그래프 라이브러리
import seaborn as sns
import matplotlib.pyplot as plt

# 통계 라이브러리 임포트
import scipy.stats as stats

# %%
df=pd.read_excel('result_data.xlsx', skiprows=1)
df
# Out:
#                      방송일시      노출(분)    마더코드    상품코드  \
# 0     2019-01-01 06:00:00  20.000000  100346  201072
# 1     2019-01-01 06:00:00        NaN  100346  201079
# 2     2019-01-01 06:20:00  20.000000  100346  201072
# 3     2019-01-01 06:20:00        NaN  100346  201079
# 4     2019-01-01 06:40:00  20.000000  100346  201072
# ...                   ...        ...     ...     ...
# 38304 2020-01-01 00:20:00  20.000000  100073  200196
# 38305 2020-01-01 00:40:00  20.000000  100073  200196
# 38306 2020-01-01 01:00:00  20.000000  100073  200196
# 38307 2020-01-01 01:20:00  20.000000  100490  201478
# 38308 2020-01-01 01:40:00  17.166667  100490  201478
#
#                             상품명 상품군   판매단가        취급액
# 0                 테이트 남성 셀린니트3종  의류  39900  2099000.0
# 1                 테이트 여성 셀린니트3종  의류  39900  4371000.0
# 2                 테이트 남성 셀린니트3종  의류  39900  3262000.0
# 3                 테이트 여성 셀린니트3종  의류  39900  6955000.0
# 4                 테이트 남성 셀린니트3종  의류  39900  6672000.0
# ...                         ...  ..    ...        ...
# 38304  삼성화재 행복한파트너 주택화재보험(1912)  무형      0        NaN
# 38305  삼성화재 행복한파트너 주택화재보험(1912)  무형      0        NaN
# 38306  삼성화재 행복한파트너 주택화재보험(1912)  무형      0        NaN
# 38307        더케이 예다함 상조서비스(티포트)  무형      0        NaN
# 38308        더케이 예다함 상조서비스(티포트)  무형      0        NaN
#
# [38309 rows x 8 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38309 entries, 0 to 38308
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   방송일시    38309 non-null  datetime64[ns]
#  1   노출(분)   21525 non-null  float64
#  2   마더코드    38309 non-null  int64
#  3   상품코드    38309 non-null  int64
#  4   상품명     38309 non-null  object
#  5   상품군     38309 non-null  object
#  6   판매단가    38309 non-null  int64
#  7   취급액     35379 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(2)
# memory usage: 2.3+ MB

# %%
#1. 무형, 보험 상품 및 판매가 0인 프로그램은 제외
df=df[df['상품군']!='무형']

# %%
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37372 entries, 0 to 38303
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   방송일시    37372 non-null  datetime64[ns]
#  1   노출(분)   20588 non-null  float64
#  2   마더코드    37372 non-null  int64
#  3   상품코드    37372 non-null  int64
#  4   상품명     37372 non-null  object
#  5   상품군     37372 non-null  object
#  6   판매단가    37372 non-null  int64
#  7   취급액     35379 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(2)
# memory usage: 2.6+ MB
#                  방송일시  노출(분)    마더코드    상품코드            상품명 상품군   판매단가  \
# 0 2019-01-01 06:00:00   20.0  100346  201072  테이트 남성 셀린니트3종  의류  39900
# 1 2019-01-01 06:00:00    NaN  100346  201079  테이트 여성 셀린니트3종  의류  39900
# 2 2019-01-01 06:20:00   20.0  100346  201072  테이트 남성 셀린니트3종  의류  39900
# 3 2019-01-01 06:20:00    NaN  100346  201079  테이트 여성 셀린니트3종  의류  39900
# 4 2019-01-01 06:40:00   20.0  100346  201072  테이트 남성 셀린니트3종  의류  39900
#
#          취급액
# 0  2099000.0
# 1  4371000.0
# 2  3262000.0
# 3  6955000.0
# 4  6672000.0

# %%
# 2. 취급액이 NaN 인경우 0으로 채워주기: 팔리지 않음
#    노출분이 NaN 인경우 ffill로 채워주기: 동일 상품 동일 노출(분)
df['노출(분)'].fillna(method='ffill', inplace=True)

# %%
df.fillna(0, inplace=True) #취급액이 NaN 인경우 0으로 채워주기: 팔리지 않음 (NaN인 열은 취급액 열 밖에 없으르모 한번에 채움)

# %%
df.info() #모든 결측값 제거 완료
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 37372 entries, 0 to 38303
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   방송일시    37372 non-null  datetime64[ns]
#  1   노출(분)   37372 non-null  float64
#  2   마더코드    37372 non-null  int64
#  3   상품코드    37372 non-null  int64
#  4   상품명     37372 non-null  object
#  5   상품군     37372 non-null  object
#  6   판매단가    37372 non-null  int64
#  7   취급액     37372 non-null  float64
# dtypes: datetime64[ns](1), float64(2), int64(3), object(2)
# memory usage: 2.6+ MB

# %%
# 3. 주문량 = 취급액/판매단가(열 생성 하기)
df['주문량']=df['취급액']/df['판매단가']

# %%
df.head()
# Out:
#                  방송일시  노출(분)    마더코드    상품코드            상품명 상품군   판매단가  \
# 0 2019-01-01 06:00:00   20.0  100346  201072  테이트 남성 셀린니트3종  의류  39900
# 1 2019-01-01 06:00:00   20.0  100346  201079  테이트 여성 셀린니트3종  의류  39900
# 2 2019-01-01 06:20:00   20.0  100346  201072  테이트 남성 셀린니트3종  의류  39900
# 3 2019-01-01 06:20:00   20.0  100346  201079  테이트 여성 셀린니트3종  의류  39900
# 4 2019-01-01 06:40:00   20.0  100346  201072  테이트 남성 셀린니트3종  의류  39900
#
#          취급액         주문량
# 0  2099000.0   52.606516
# 1  4371000.0  109.548872
# 2  3262000.0   81.754386
# 3  6955000.0  174.310777
# 4  6672000.0  167.218045

# %%
# 4. 심야 2:00 ~ 6:20 시간대 제외
#    요일 열 새로 생성 0~6 월~일요일, 중 토요일 (18:00~18:20 제외)

df['요일']=df['방송일시'].dt.dayofweek

# %%
df.index = df['방송일시']

# %%
df[df['요일']==5].between_time('17:00', '18:21') #토요일 18:00~18:20 은 이미 포함되지 않은 상태를 확인
# Out:
#                                    방송일시  노출(분)    마더코드    상품코드  \
# 방송일시
# 2019-01-05 17:00:00 2019-01-05 17:00:00   20.0  100435  201350
# 2019-01-05 17:20:00 2019-01-05 17:20:00   20.0  100435  201350
# 2019-01-05 17:40:00 2019-01-05 17:40:00   20.0  100435  201350
# 2019-01-05 18:20:00 2019-01-05 18:20:00   20.0  100801  202365
# 2019-01-12 17:00:00 2019-01-12 17:00:00   20.0  100491  201483
# ...                                 ...    ...     ...     ...
# 2019-12-21 17:20:00 2019-12-21 17:20:00   20.0  100418  201322
# 2019-12-21 17:40:00 2019-12-21 17:40:00   20.0  100418  201322
# 2019-12-28 17:00:00 2019-12-28 17:00:00   20.0  100202  201018
# 2019-12-28 17:20:00 2019-12-28 17:20:00   20.0  100253  200864
# 2019-12-28 17:40:00 2019-12-28 17:40:00   20.0  100253  200864
#
#                                               상품명  상품군   판매단가          취급액  \
# 방송일시
# 2019-01-05 17:00:00                우리바다 손질왕꼬막 24팩  농수축  39900   52050000.0
# 2019-01-05 17:20:00                우리바다 손질왕꼬막 24팩  농수축  39900   77249000.0
# 2019-01-05 17:40:00                우리바다 손질왕꼬막 24팩  농수축  39900  104552000.0
# 2019-01-05 18:20:00              바다먹자 국내산 손질꽃게 7팩  농수축  59900   26816000.0
# 2019-01-12 17:00:00  피시원 국내산 손질 대구 8팩 * 매운탕 양념 8팩  농수축  59900   22580000.0
# ...                                           ...  ...    ...          ...
# 2019-12-21 17:20:00              코몽트 덤블 플리스 자켓 2종   의류  39900   32891000.0
# 2019-12-21 17:40:00              코몽트 덤블 플리스 자켓 2종   의류  39900  223492000.0
# 2019-12-28 17:00:00               임성근의 녹용도가니탕 풀세트  농수축  55900   56234000.0
# 2019-12-28 17:20:00                    안동간고등어 20팩  농수축  30900   37621000.0
# 2019-12-28 17:40:00                    안동간고등어 20팩  농수축  30900   73063000.0
#
#                              주문량  요일
# 방송일시
# 2019-01-05 17:00:00  1304.511278   5
# 2019-01-05 17:20:00  1936.065163   5
# 2019-01-05 17:40:00  2620.350877   5
# 2019-01-05 18:20:00   447.679466   5
# 2019-01-12 17:00:00   376.961603   5
# ...                          ...  ..
# 2019-12-21 17:20:00   824.335840   5
# 2019-12-21 17:40:00  5601.303258   5
# 2019-12-28 17:00:00  1005.974955   5
# 2019-12-28 17:20:00  1217.508091   5
# 2019-12-28 17:40:00  2364.498382   5
#
# [180 rows x 10 columns]

# %%
# 심야 2:00 ~ 6:20 시간대 제외
df.between_time('2:00','6:19')
# Out:
#                                    방송일시  노출(분)    마더코드    상품코드  \
# 방송일시
# 2019-01-01 06:00:00 2019-01-01 06:00:00   20.0  100346  201072
# 2019-01-01 06:00:00 2019-01-01 06:00:00   20.0  100346  201079
# 2019-01-02 06:00:00 2019-01-02 06:00:00   20.0  100229  200800
# 2019-01-03 06:00:00 2019-01-03 06:00:00   20.0  100781  202292
# 2019-01-03 06:00:00 2019-01-03 06:00:00   20.0  100781  202285
# ...                                 ...    ...     ...     ...
# 2019-12-26 02:00:00 2019-12-26 02:00:00   20.0  100624  201927
# 2019-12-27 02:00:00 2019-12-27 02:00:00   20.0  100312  201006
# 2019-12-28 02:00:00 2019-12-28 02:00:00   20.0  100841  202484
# 2019-12-29 02:00:00 2019-12-29 02:00:00   20.0  100723  202114
# 2019-12-31 02:00:00 2019-12-31 02:00:00   20.0  100439  201357
#
#                                           상품명   상품군   판매단가         취급액  \
# 방송일시
# 2019-01-01 06:00:00             테이트 남성 셀린니트3종    의류  39900   2099000.0
# 2019-01-01 06:00:00             테이트 여성 셀린니트3종    의류  39900   4371000.0
# 2019-01-02 06:00:00            벨라홈 논슬립 옷걸이 세트  생활용품  29800   9605000.0
# 2019-01-03 06:00:00               에펨 여성 미들퍼부츠    잡화  39800   2450000.0
# 2019-01-03 06:00:00               에펨 남성 미들퍼부츠    잡화  49800   2645000.0
# ...                                       ...   ...    ...         ...
# 2019-12-26 02:00:00          안국루테인 미니100(5박스)  건강기능  59000  18822000.0
# 2019-12-27 02:00:00  블랙모어스 알티지 오메가3 3병 (53주분)  건강기능  95200  16867000.0
# 2019-12-28 02:00:00        옛날 그 쥐포 110장 (11팩)   농수축  32900  33231000.0
# 2019-12-29 02:00:00           아이앤아이 퀵래쉬 속눈썹세트   이미용  59000  36540000.0
# 2019-12-31 02:00:00      루시헨느 레이스 홀리데이 란쥬 패키지    속옷  89900  29452000.0
#
#                              주문량  요일
# 방송일시
# 2019-01-01 06:00:00    52.606516   1
# 2019-01-01 06:00:00   109.548872   1
# 2019-01-02 06:00:00   322.315436   2
# 2019-01-03 06:00:00    61.557789   3
# 2019-01-03 06:00:00    53.112450   3
# ...                          ...  ..
# 2019-12-26 02:00:00   319.016949   3
# 2019-12-27 02:00:00   177.174370   4
# 2019-12-28 02:00:00  1010.060790   5
# 2019-12-29 02:00:00   619.322034   6
# 2019-12-31 02:00:00   327.608454   1
#
# [473 rows x 10 columns]

# %%
df=df.drop(df.between_time('2:00','6:19').index)
df['일시'] = df['방송일시']
df
# 상품군으로 groupby 해서 볼까
# Out:
#                                    방송일시  노출(분)    마더코드    상품코드  \
# 방송일시
# 2019-01-01 06:20:00 2019-01-01 06:20:00   20.0  100346  201072
# 2019-01-01 06:20:00 2019-01-01 06:20:00   20.0  100346  201079
# 2019-01-01 06:40:00 2019-01-01 06:40:00   20.0  100346  201072
# 2019-01-01 06:40:00 2019-01-01 06:40:00   20.0  100346  201079
# 2019-01-01 07:00:00 2019-01-01 07:00:00   20.0  100305  200974
# ...                                 ...    ...     ...     ...
# 2019-12-31 23:40:00 2019-12-31 23:40:00   20.0  100448  201391
# 2020-01-01 00:00:00 2020-01-01 00:00:00   20.0  100448  201383
# 2020-01-01 00:00:00 2020-01-01 00:00:00   20.0  100448  201390
# 2020-01-01 00:00:00 2020-01-01 00:00:00   20.0  100448  201384
# 2020-01-01 00:00:00 2020-01-01 00:00:00   20.0  100448  201391
#
#                                   상품명 상품군    판매단가          취급액         주문량  \
# 방송일시
# 2019-01-01 06:20:00     테이트 남성 셀린니트3종  의류   39900    3262000.0   81.754386
# 2019-01-01 06:20:00     테이트 여성 셀린니트3종  의류   39900    6955000.0  174.310777
# 2019-01-01 06:40:00     테이트 남성 셀린니트3종  의류   39900    6672000.0  167.218045
# 2019-01-01 06:40:00     테이트 여성 셀린니트3종  의류   39900    9337000.0  234.010025
# 2019-01-01 07:00:00  오모떼 레이스 파운데이션 브라  속옷   59000    6819000.0  115.576271
# ...                               ...  ..     ...          ...         ...
# 2019-12-31 23:40:00     일시불쿠첸압력밥솥 6인용  주방  148000   10157000.0   68.628378
# 2020-01-01 00:00:00    무이자쿠첸압력밥솥 10인용  주방  178000   50929000.0  286.117978
# 2020-01-01 00:00:00    일시불쿠첸압력밥솥 10인용  주방  168000  104392000.0  621.380952
# 2020-01-01 00:00:00     무이자쿠첸압력밥솥 6인용  주방  158000   13765000.0   87.120253
# 2020-01-01 00:00:00     일시불쿠첸압력밥솥 6인용  주방  148000   46608000.0  314.918919
#
#                      요일                  일시
# 방송일시
# 2019-01-01 06:20:00   1 2019-01-01 06:20:00
# 2019-01-01 06:20:00   1 2019-01-01 06:20:00
# 2019-01-01 06:40:00   1 2019-01-01 06:40:00
# 2019-01-01 06:40:00   1 2019-01-01 06:40:00
# 2019-01-01 07:00:00   1 2019-01-01 07:00:00
# ...                  ..                 ...
# 2019-12-31 23:40:00   1 2019-12-31 23:40:00
# 2020-01-01 00:00:00   2 2020-01-01 00:00:00
# 2020-01-01 00:00:00   2 2020-01-01 00:00:00
# 2020-01-01 00:00:00   2 2020-01-01 00:00:00
# 2020-01-01 00:00:00   2 2020-01-01 00:00:00
#
# [36899 rows x 11 columns]

# %%
df.to_csv('result4Analysis.csv', index=False)

# %%
# groupby 상품군으로 분석해보기

# %%
#### 날씨 데이터 추가염 ㅎ_ㅎ ####
weather = pd.read_csv("weather_data.csv",encoding='CP949')
weather
# Out:
#        지점 지점명                일시  기온(°C)  강수량(mm)  풍속(m/s)  풍향(16방위)  습도(%)  \
# 0     108  서울   2019-01-01 6:00    -7.9      NaN      1.3     290.0   60.0
# 1     108  서울   2019-01-01 7:00    -7.7      NaN      1.3     320.0   58.0
# 2     108  서울   2019-01-01 8:00    -7.7      NaN      0.9     360.0   57.0
# 3     108  서울   2019-01-01 9:00    -7.0      NaN      0.9     290.0   50.0
# 4     108  서울  2019-01-01 10:00    -4.9      NaN      1.6     290.0   44.0
# ...   ...  ..               ...     ...      ...      ...       ...    ...
# 8750  108  서울  2019-12-31 20:00    -7.0      NaN      2.9     290.0   41.0
# 8751  108  서울  2019-12-31 21:00    -7.4      NaN      0.8      20.0   43.0
# 8752  108  서울  2019-12-31 22:00    -8.2      NaN      0.0       0.0   42.0
# 8753  108  서울  2019-12-31 23:00    -7.4      NaN      0.0       0.0   45.0
# 8754  108  서울   2020-01-01 0:00    -6.5      0.0      0.0       0.0   38.0
#
#       적설(cm)  지면상태(지면상태코드)
# 0        NaN           NaN
# 1        NaN           NaN
# 2        NaN           NaN
# 3        NaN           NaN
# 4        NaN           NaN
# ...      ...           ...
# 8750     NaN           NaN
# 8751     NaN           NaN
# 8752     NaN           NaN
# 8753     NaN           NaN
# 8754     NaN           NaN
#
# [8755 rows x 10 columns]

# %%
# 타입: object -> datetime 변경
weather['일시'] = pd.to_datetime(weather['일시'])
weather['일시']
# Out:
# 0      2019-01-01 06:00:00
# 1      2019-01-01 07:00:00
# 2      2019-01-01 08:00:00
# 3      2019-01-01 09:00:00
# 4      2019-01-01 10:00:00
#                ...
# 8750   2019-12-31 20:00:00
# 8751   2019-12-31 21:00:00
# 8752   2019-12-31 22:00:00
# 8753   2019-12-31 23:00:00
# 8754   2020-01-01 00:00:00
# Name: 일시, Length: 8755, dtype: datetime64[ns]

# %%
# 필요 없는 컬럼 제거
weather = weather.drop('지점',axis = 1)
weather = weather.drop('지점명',axis = 1)
weather = weather.drop('지면상태(지면상태코드)',axis = 1)

# %%
# nan을 0으로 변경 (목적: 추후 merge 후 nan으로 있으면 안되니까)
weather = weather.replace(np.nan, '0')

# %%
# df와 weather merge / 일시를 기준으로 / outer로 하여 합집합 개념으로 진행.
df_new = pd.merge(df,weather, on='일시', how='outer')

# %%
# 아래에서 위로 채우기 bfill -> nan 데이터 제거 dropna -> '일시' 컬럼 제거
df_new = df_new.fillna(method = 'bfill')
df_new = df_new.dropna()
df_new = df_new.drop('일시',axis = 1)

# %%
# df와 df_new의 shape이 같음을 확인.
print(df.shape)
print(df_new.head())
# Out:
# (36899, 11)
#                  방송일시  노출(분)      마더코드      상품코드               상품명 상품군  \
# 0 2019-01-01 06:20:00   20.0  100346.0  201072.0     테이트 남성 셀린니트3종  의류
# 1 2019-01-01 06:20:00   20.0  100346.0  201079.0     테이트 여성 셀린니트3종  의류
# 2 2019-01-01 06:40:00   20.0  100346.0  201072.0     테이트 남성 셀린니트3종  의류
# 3 2019-01-01 06:40:00   20.0  100346.0  201079.0     테이트 여성 셀린니트3종  의류
# 4 2019-01-01 07:00:00   20.0  100305.0  200974.0  오모떼 레이스 파운데이션 브라  속옷
#
#       판매단가        취급액         주문량   요일  기온(°C) 강수량(mm) 풍속(m/s) 풍향(16방위)  \
# 0  39900.0  3262000.0   81.754386  1.0    -7.7       0     1.3      320
# 1  39900.0  6955000.0  174.310777  1.0    -7.7       0     1.3      320
# 2  39900.0  6672000.0  167.218045  1.0    -7.7       0     1.3      320
# 3  39900.0  9337000.0  234.010025  1.0    -7.7       0     1.3      320
# 4  59000.0  6819000.0  115.576271  1.0    -7.7       0     1.3      320
#
#    습도(%) 적설(cm)
# 0   58.0      0
# 1   58.0      0
# 2   58.0      0
# 3   58.0      0
# 4   58.0      0

# %%
df_new.corr()
# Out:
#            노출(분)      마더코드      상품코드      판매단가       취급액       주문량        요일  \
# 노출(분)   1.000000  0.094999  0.086022  0.147808  0.026321 -0.064054 -0.007324
# 마더코드    0.094999  1.000000  0.978881 -0.214975 -0.028782  0.012116 -0.038249
# 상품코드    0.086022  0.978881  1.000000 -0.227482 -0.015380  0.023031 -0.038538
# 판매단가    0.147808 -0.214975 -0.227482  1.000000 -0.253608 -0.383704  0.070732
# 취급액     0.026321 -0.028782 -0.015380 -0.253608  1.000000  0.769884  0.055887
# 주문량    -0.064054  0.012116  0.023031 -0.383704  0.769884  1.000000  0.016090
# 요일     -0.007324 -0.038249 -0.038538  0.070732  0.055887  0.016090  1.000000
# 기온(°C)  0.027973 -0.095006 -0.113018  0.010468 -0.003342  0.037455  0.015719
# 습도(%)   0.000133 -0.036513 -0.041606  0.056550 -0.064444 -0.072253 -0.023083
#
#           기온(°C)     습도(%)
# 노출(분)   0.027973  0.000133
# 마더코드   -0.095006 -0.036513
# 상품코드   -0.113018 -0.041606
# 판매단가    0.010468  0.056550
# 취급액    -0.003342 -0.064444
# 주문량     0.037455 -0.072253
# 요일      0.015719 -0.023083
# 기온(°C)  1.000000  0.161593
# 습도(%)   0.161593  1.000000

# %%
fig=sns.jointplot(df_new['취급액'],df_new['기온(°C)'], kind='kde')
fig.annotate(stats.pearsonr)
# 상관관계 너무 구림.
# p -> 0.05가 나와야 의미있음 -> 100번 중 95번이 같은 경과 나옴

# %%
from datetime import date, datetime
 
MON, TUE, WED, THU, FRI, SAT, SUN = range(7)
 
class holiday2019():
    HOLIDAYS = ((1,1), # new Year
                (2,4), # new Year0
                (2,5), # new Year1
                (2,6), # new Year2
                (3,1), # 3.1
                (5,5), # Children's Day
                (5,6), # Make up Holiday
                (5,12), # Buddha Day
                (6,6), # Memorial Day
                (8,15), # Liberation Day
                (9,12), # Thanksgiving0
                (9,13), # Thanksgiving1
                (9,14), # Thanksgiving2
                (10,3), # National Foundation Day
                (10,9), # Hangul Day
                (12,25) # Christmas
                )
 
    def is_holiday(self, daytuple):
        HOLIDAYS = self.HOLIDAYS
        if daytuple in HOLIDAYS:
            return True
        else:
            return False

# %%
l = []
if __name__=='__main__':
    for i in df_new['방송일시']:
        now = i
        daytuple = ((now.month),(now.day))
        nowholiday = holiday2019()
        l.append(nowholiday.is_holiday(daytuple))

# %%
holiday = pd.Series(l).astype(int)

# %%
df_new['휴일'] = holiday

# %%
df_new

# %%
list2 = []
for i in df_new['방송일시']:
    list2.append(i.weekday())
weekday = pd.Series(list2)

# %%
df_new['요일'] = weekday

# %%
df_new

# %%
df_new.loc[df_new['휴일'] == 1, 'resting_day'] = True
df_new.loc[df_new['휴일'] == 0, 'working_day'] = True

df_new['working_day'].fillna(False, inplace = True)
df_new['resting_day'].fillna(False, inplace = True)

# %%
df_new.loc[df_new['요일'] == 0, '월'] = True
df_new.loc[df_new['요일'] == 1, '화'] = True
df_new.loc[df_new['요일'] == 2, '수'] = True
df_new.loc[df_new['요일'] == 3, '목'] = True
df_new.loc[df_new['요일'] == 4, '금'] = True
df_new.loc[df_new['요일'] == 5, '토'] = True
df_new.loc[df_new['요일'] == 6, '일'] = True

df_new['월'].fillna(False, inplace = True)
df_new['화'].fillna(False, inplace = True)
df_new['수'].fillna(False, inplace = True)
df_new['목'].fillna(False, inplace = True)
df_new['금'].fillna(False, inplace = True)
df_new['토'].fillna(False, inplace = True)
df_new['일'].fillna(False, inplace = True)

# %%
col = ['취급액','주문량','월','화','수','목','금','토','일','요일','휴일','resting_day','working_day','노출(분)']
df_zip = df_new[col]

# %%
df_zip

# %%
df_zip_corr = df_zip.corr()
mask = np.array(df_zip_corr)
mask[np.tril_indices_from(mask)] = False

# %%
plt.figure(figsize = (20,10))
heat = sns.heatmap(df_zip_corr,square = True, annot = True, vmax = 0.7)

# %%
df_new_corr = df_new.corr()
mask = np.array(df_new_corr)
mask[np.tril_indices_from(mask)] = False
plt.figure(figsize = (20,10))
heat = sns.heatmap(df_new_corr,square = True, annot = True, vmax = 0.7)

# %%
# fig, (ax1, ax2) = plt.subplots(ncols = 2)
# fig.set_size_inches(20,5)
# fig, ax3 = plt.subplots()
# fig.set_size_inches(20,5)
# fig, ax4 = plt.subplots()
# fig.set_size_inches(20,5)
# fig, ax5 = plt.subplots()
# fig.set_size_inches(20,5)
# sns.barplot(data = df_new, x = '휴일',y = '취급액',ax=ax1)
# sns.barplot(data = df_new, x = '요일',y = '취급액',ax=ax2)
# sns.barplot(data = df_new, x = '기온(°C)',y = '취급액',ax=ax3)
# sns.barplot(data = df_new, x = '습도(%)',y = '취급액',ax=ax4)
# sns.barplot(data = df_new, x = '방송일시',y = '취급액',ax=ax5)

# %%
# Ipyparallel 적용 확인해보기
