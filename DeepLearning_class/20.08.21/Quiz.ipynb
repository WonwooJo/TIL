# %% [markdown]
# ### 연습문제
# #### 1. 금융데이터에 대해
#  - 4개 features에 대해 상관관계 및 공분산 구하기
#  - 공분산, 상관계수
#  - GOOG과 양의 상관관계, 음의 상관관계가 가장 큰 회사 출력

# %%
import pandas as pd
import numpy as np
import pandas_datareader.data as web
allData = {ticker: web.get_data_yahoo(ticker) for ticker in ['AAPL','IBM','MSFT','GOOG']}
allData
# Out:
# {'AAPL':                   High         Low        Open       Close       Volume  \
#  Date
#  2015-08-24  108.800003   92.000000   94.870003  103.120003  162206300.0
#  2015-08-25  111.110001  103.500000  111.110001  103.739998  103601600.0
#  2015-08-26  109.889999  105.050003  107.089996  109.690002   96774600.0
#  2015-08-27  113.239998  110.019997  112.230003  112.919998   84616100.0
#  2015-08-28  113.309998  111.540001  112.169998  113.290001   53164400.0
#  ...                ...         ...         ...         ...          ...
#  2020-08-14  460.000000  452.179993  459.320007  459.630005   41391300.0
#  2020-08-17  464.350006  455.850006  464.250000  458.429993   29890400.0
#  2020-08-18  464.000000  456.029999  457.410004  462.250000   26408400.0
#  2020-08-19  468.649994  462.440002  463.929993  462.829987   36384500.0
#  2020-08-20  473.570007  462.929993  463.000000  473.100006   31565000.0
#
#               Adj Close
#  Date
#  2015-08-24   95.294647
# ...

# %%
price = pd.DataFrame({ticker: data['Adj Close'] for ticker, data in allData.items()})
price
# Out:
#                   AAPL         IBM        MSFT         GOOG
# Date
# 2015-08-24   95.294647  114.890862   37.878582   589.609985
# 2015-08-25   95.867607  112.880898   36.778946   582.059998
# 2015-08-26  101.366074  117.477425   38.814651   628.619995
# 2015-08-27  104.350983  118.950912   39.896111   637.609985
# 2015-08-28  104.692871  118.502495   39.923386   630.380005
# ...                ...         ...         ...          ...
# 2020-08-14  459.630005  125.269997  208.396240  1507.729980
# 2020-08-17  458.429993  124.440002  209.772919  1517.979980
# 2020-08-18  462.250000  124.919998  210.979996  1558.599976
# 2020-08-19  462.829987  123.839996  209.699997  1547.530029
# 2020-08-20  473.100006  123.150002  214.580002  1581.750000
#
# [1258 rows x 4 columns]

# %%
# 공분산
price.cov()
# Out:
#               AAPL         IBM         MSFT          GOOG
# AAPL   5592.295046   21.920387  3213.475247  16473.981082
# IBM      21.920387  124.846741    -0.289846    370.818407
# MSFT   3213.475247   -0.289846  1984.185614   9984.636632
# GOOG  16473.981082  370.818407  9984.636632  56071.865232

# %%
# 상관계수
price.corr()
# Out:
#           AAPL       IBM      MSFT      GOOG
# AAPL  1.000000  0.026234  0.964692  0.930317
# IBM   0.026234  1.000000 -0.000582  0.140152
# MSFT  0.964692 -0.000582  1.000000  0.946605
# GOOG  0.930317  0.140152  0.946605  1.000000

# %%
# GOOG와 가장 큰 양의 상관관계: MSFT
# GOOG와 가장 큰 음의 상관관계: 없음.

# %% [markdown]
# #### 2. 에볼라 데이터에 대해,
#
# - 각 국가별 발병자 수 평균을 구했을 때, 평균값이 가장 큰 국가명을 출력하시오.
#
# - 각 국가별 발병자 수 컬럼값에 대해, NaN이 가장 많은 국가명을 출력하시오.
#
# - 각 국가별 사망자 수가 가장 많은 국가명 및 사망자수를 출력하시오.
#
# - 전체 사망자 수를 구하시오.
#
# - 전체 발병자 수를 구하시오.

# %%
ebola = pd.read_csv('data/country_timeseries.csv')
ebola
# Out:
#            Date  Day  Cases_Guinea  Cases_Liberia  Cases_SierraLeone  \
# 0      1/5/2015  289        2776.0            NaN            10030.0
# 1      1/4/2015  288        2775.0            NaN             9780.0
# 2      1/3/2015  287        2769.0         8166.0             9722.0
# 3      1/2/2015  286           NaN         8157.0                NaN
# 4    12/31/2014  284        2730.0         8115.0             9633.0
# ..          ...  ...           ...            ...                ...
# 117   3/27/2014    5         103.0            8.0                6.0
# 118   3/26/2014    4          86.0            NaN                NaN
# 119   3/25/2014    3          86.0            NaN                NaN
# 120   3/24/2014    2          86.0            NaN                NaN
# 121   3/22/2014    0          49.0            NaN                NaN
#
#      Cases_Nigeria  Cases_Senegal  Cases_UnitedStates  Cases_Spain  \
# 0              NaN            NaN                 NaN          NaN
# ...

# %%
# 각 국가별 발병자 수 평균을 구했을 때, 평균값이 가장 큰 국가명
ebola.mean().iloc[1:9].keys()[ebola.mean().iloc[1:9].argmax()]
# Out:
# 'Cases_SierraLeone'

# %%
# 각 국가별 발병자 수 컬럼값에 대해, NaN이 가장 많은 국가명
ebola.loc[:'Cases_Mali'].values_counts
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-139-7931d2434dfc> in <module>
#       1 # 각 국가별 발병자 수 컬럼값에 대해, NaN이 가장 많은 국가명
# ----> 2 ebola.loc[:'Cases_Mali'].values_counts
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'values_counts'

# %%
# 각 국가별 사망자 수가 가장 많은 국가명 및 사망자수를 출력
ebola.mean().iloc[1:9].keys()[ebola.mean().iloc[1:9].argmax()]

# %%
ebola.apply(lambda x: x.sum())
# Out:
# Date                   1/5/20151/4/20151/3/20151/2/201512/31/201412/2...
# Day                                                                17663
# Cases_Guinea                                                       84729
# Cases_Liberia                                                     193833
# Cases_SierraLeone                                                 211181
# Cases_Nigeria                                                        636
# Cases_Senegal                                                         27
# Cases_UnitedStates                                                    59
# Cases_Spain                                                           16
# Cases_Mali                                                            42
# Deaths_Guinea                                                      51818
# Deaths_Liberia                                                     89198
# Deaths_SierraLeone                                                 60352
# ...

# %% [markdown]
# #### 3. 갭 마인더 데이터에 대해,
#
# - 국가별로 그룹화를 한 다음, 그룹 단위로 gdp의 평균을 출력하시오.
#
# - 대륙별로 그룹화를 한 다음, 그룹 단위로 기대수명의 평균을 출력하시오.

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-122-de4240587d79> in <module>
#       1 a=(1,2,3,4)
# ----> 2 a[a>2]
#
# TypeError: '>' not supported between instances of 'tuple' and 'int'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-138-62262fe700ad> in <module>
# ----> 1 count(3)
#
# TypeError: 'int' object is not callable

# %%
allData1 = {ticker: web.get_data_yahoo(ticker) for ticker in ['AAPL','IBM','MSFT','GOOG','TSLA','NVDA','TSM','NKLA','SPCE','BA','AMZN','BRK-B']}

# %%
price5 = pd.DataFrame({ticker: data['Adj Close'] for ticker, data in allData1.items()})
price5
# Out:
#                   AAPL         IBM        MSFT         GOOG         TSLA  \
# Date
# 2015-08-24   95.294647  114.890862   37.878582   589.609985   218.869995
# 2015-08-25   95.867607  112.880898   36.778946   582.059998   220.029999
# 2015-08-26  101.366074  117.477425   38.814651   628.619995   224.839996
# 2015-08-27  104.350983  118.950912   39.896111   637.609985   242.990005
# 2015-08-28  104.692871  118.502495   39.923386   630.380005   248.479996
# ...                ...         ...         ...          ...          ...
# 2020-08-14  459.630005  125.269997  208.396240  1507.729980  1650.709961
# 2020-08-17  458.429993  124.440002  209.772919  1517.979980  1835.640015
# 2020-08-18  462.250000  124.919998  210.979996  1558.599976  1887.089966
# 2020-08-19  462.829987  123.839996  209.699997  1547.530029  1878.530029
# 2020-08-20  473.100006  123.150002  214.580002  1581.750000  2001.829956
#
#                   NVDA        TSM       NKLA       SPCE          BA  \
# Date
# ...

# %%
price1 = price5.drop(price5.index[:1005])
price1
# Out:
#                   AAPL         IBM        MSFT         GOOG         TSLA  \
# Date
# 2019-08-21  210.550949  127.899323  137.227707  1191.250000   220.830002
