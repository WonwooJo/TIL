# %%
# 무선청소기 가격, 성능
# http://search.danawa.com/dsearch.php?query=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&tab=main

# %%
from selenium import webdriver

# %%
driver=webdriver.Chrome("c:/mychrome/chromedriver.exe")
url="http://search.danawa.com/dsearch.php?query=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&tab=main"

# %%
driver.get(url)

# %%
from bs4 import BeautifulSoup

# %%
html=driver.page_source
html
# Out:
# '<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="ko" lang="ko" class=" js no-touch"><head>\n<title>무선청소기 쇼핑검색 종합정보 :: 행복쇼핑의 시작 ! 다나와 (가격비교) - Danawa.com</title>\n<!-- <meta http-equiv="Content-Type" content="text/html; charset=utf-8"/> -->\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8"><meta http-equiv="X-UA-Compatible" content="IE=Edge"><meta name="Title" content="무선청소기 쇼핑검색 종합정보 :: 행복쇼핑의 시작 ! 다나와 (가격비교) - Danawa.com">\n<meta name="Description" content="무선청소기 최저가 상품 가격비교와 함께 사용기, 뉴스, 리뷰, 구매가이드, 중고시세 등의 쇼핑 추천정보를 풍부하게 제공합니다.">\n<meta name="Keywords" content="무선청소기, 상품 추천, 구매, 구입, 쇼핑 검색, 가격 비교, 중고, 좋은, 뉴스, 사용기, 리뷰, 블로그, 최저가">\n<meta name="robots" content="nofollow">\n<meta property="og:title" content="쇼핑검색 종합정보">\n<meta property="og:image" content="http://img.danawa.com/new/tour/img/logo/sns_danawa.jpg">\n<meta property="og:description" content="무선청소기">\n<meta content="width=1280" name="viewport">\n<link rel="shortcut icon" href="//img.danawa.com/new/danawa_main/v1/img/danawa_favicon.ico">\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/new/recss/common.css?v=2008061111">\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/new/recss/navigation.css?v=2008061111">\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/new/recss/wish_pop.css?v=2008061111">\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/new/recss/dictionary.css?v=2006290911">\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/new/recss/search_renew.css?v=2006290911">\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/new/recss/shopping_clip.css?v=2006290911">\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/new/recss/dpg_stamp.css?v=2006290911">\n<script async="" charset="utf-8" src="//static.dable.io/dist/plugin.min.js"></script><script type="text/javascript" async="" src="https://www.google-analytics.com/analytics.js"></script><script type="text/javascript" src="//static.danawa.com/globaljs/external/jquery/core/last/jquery-last.min.js?v=2007081800"></script>\n<script type="text/javascript" charset="euc-kr" src="/globaljs/com/danawa/common/gnb_ui.js?v=2007081800"></script>\n<script type="text/javascript" charset="euc-kr" src="/globaljs/com/danawa/common/jquery.addProductToWishList.js?v=2007081800"></script>\n<script type="text/javascript" src="//static.danawa.com/globaljs/external/jquery/plugin/jquery.cookie/jquery.cookie.js"></script>\n<script type="text/javascript" charset="utf-8" src="//static.danawa.com/globaljs/com/danawa/common/searchAutocompleteLayer_UTF8.js?v=2007081800"></script>\n</head>\n<body>\n<div id="skip_navigation">\n    <a href="#danawa_header"><span>메인 메뉴로 바로가기</span></a>\n    <a href="#danawa_content"><span>본문으로 바로가기</span></a>\n</div>\n\n<div id="danawa_wrap" class="danawa_product_list aside_show">\n\t<div id="danawa_header_fixed" style="display: block;">\n\t\t<div class="inner_wrap" style="">\n\t\t\t<h1 class="sub_h1"><a href="http://www.danawa.com"><img src="//img.danawa.com/new/searchNew/img/re/fixed_logo.png" alt="다나와"></a></h1>\n\n\t\t\t<form id="fixedSearchre" name="fixedSearchre" method="get" action="http://search.danawa.com/dsearch.php">\n\t\t\t<div class="search_area">\n\t\t\t\t<fieldset>\n\t\t\t\t\t<legend>검색</legend>\n\t\t\t\t\t<div class="search_area_content" id="fixedSearchArea">\n\t\t\t\t\t\t<input type="text" value="" name="query" class="search_words_insert fixed_search" id="FixedAKCSearch" title="검색어 입력" autocomplete="off">\n\n\t\t\t\t\t\t<button class="btn_search_submit"><span>검색</span></button>\n\t\t\t\t\t<div id="auto_area2" class="auto_complete_area" style="display: none;"><div id="akcLayer" class="auto_word_list"><div id="myFixedAutoKeywordBlockArea"><div></div><div class="func_opt"><a href="#danawa_header_fixed" class="com_gnb auto_function_switch" onclick="return false;" id="function_switch_keyword">닫기</a></div></div><div id="myFixedSearchKeywordBlockArea" style="display: none;"><div><dl c ...

# %%
soup=BeautifulSoup(html, "html.parser")

# %%
prod_items=soup.select("li.prod_item")
len(prod_items)
# Out:
# 50

# %%
len(soup.select("ul.product_list > li.prod_item"))
# Out:
# 50

# %%
prod_items=soup.select("div.main_prodlist > ul.product_list > li.prod_item")

# %%
#델로라 V11 파워 300W
title=prod_items[0].select("p.prod_name > a")[0].text.strip()
title
# Out:
# '델로라 V11 파워 300W'

# %%
spec_list=prod_items[0].select("div.spec_list")[0].text.strip()

# %%
#135330
price=prod_items[0].select("p.price_sect > a > strong")
[0].text.strip().replace(",","")

# for i in range(10):
#     print(prod_items[i].select("p.price_sect > a > strong"))
    #prod_items[1].select("p.price_sect > a > strong")

# %%
#반복문으로 1페이지 검색 결과에 대해 상품 정보 추출
prod_data=[]
for prod_item in prod_items:
    #상품명
    try:
        title=prod_item.select("p.prod_name > a")[0].text.strip()
    except:
        title=""
    #스펙리스트
    try:
        spec_list=prod_item.select("div.spec_list")[0].text.strip()
    #가격정보
    except:
        spec_list=""
    try:
        price=prod_item.select("p.price_sect > a > strong")[0].text.strip().replace(",","")
    except:
        price=0
    prod_data.append([title, spec_list, price])

print(len(prod_data))
prod_data
# Out:
# 41
# [['델로라 V11 파워 300W',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 29.6V / 헤파필터 / 싸이클론 / 4단계여과 / BLDC모터 / 흡입력: 22000Pa / 먼지통용량: 0.6L / 충전시간: 5시간 / 사용시간: 1시간10분 / 배터리: 리튬이온 / 용량: 2500mAh / 브러쉬: 바닥, 솔형, 틈새, 침구, 연장관 / LED라이트 / 거치대 / 무게: 3.89kg / 색상:레드, 블랙 / 소비전력: 300W / 크기(가로x세로x깊이): 239x1255x105mm',
#   '135330'],
#  ['샤오미 차량용 청소기 무선 3세대 (해외구매)',
#   '차량용청소기 / 무선 / 흡입력: 16,800Pa / 헤파필터 / 추가노즐: 틈새, 솔브러쉬, 연장호스 / 사용시간: 25분 / 크기 : 369x72mm / 무게 : 560g',
#   '58790'],
#  ['LG전자 코드제로 A9S A9700',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 헤파필터 / 2중터보싸이클론 / 5단계여과 / 인버터모터 / 흡입력: 200W / 충전시간: 4시간 / 사용시간: 2시간 / 배터리: 리튬이온 (2개) / 브러쉬: 바닥, 솔형, 틈새, 침구, 매트리스, 물걸레, 연장관 / 거치대 / 디스플레이표시창 / 배터리잔량표시 / WiFi / 색상:판타지실버 / 소비전력: 590W / 미세먼지인증(SLG) / 3단계물분사조절 / 크기(가로x세로x깊이): 250x1120x260mm',
#   '1022240'],
#  ['다이슨 V8 플러피',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 21.6V / 싸이클론 / 흡입력: 155AW / 충전시간: 5시간 / 사용시간: 40분 / 배터리: 리튬이온 / 도킹스테이션 / 무게: 2.58kg / 브러쉬: 소프트롤러클리너헤드, 미니모터, 소프트더스팅, 콤비네이션툴, 크레비스툴, 매트리스툴, 연장호스 / 크기(가로x세로x깊이): 250x1264x224mm',
#   '456520'],
#  ['LG전자 코드제로 A9S A9570',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 헤파필터 / 2중터보싸이클론 / 5단계여과 / 인버터모터 / 흡입력: 200W / 충전시간: 4시간 / 사용시간: 2시간 / 배터리: 리튬이온 (2개) / 브러쉬: 바닥, 솔형, 틈새, 침구, 매트리스, 물걸레 / 거치대 / 디스플레이표시창 / 배터리잔량표시 / WiFi / 색상:판타지실버 / 소비전력: 590W / 미세먼지인증(SLG) / 3단계물분사조절 / 크기(가로x세로x깊이): 250x1120x260mm',
#   '954720'],
#  ['샤오미 드리미 V10',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 25.2V / 헤파필터 / H12급 / 5단계여과 / 흡입력: 140AW / 흡입력: 22000Pa / 먼지통용량: 0.5L / 충전시간: 3시간30분 / 사용시간: 1시간 / 용량: 2500mAh / 브러쉬: 바닥, 솔형, 틈새, 침구, 연장관 / 거치대 / 무게: 1.5kg / 색상:화이트 / 소비전력: 450W',
#   '163120'],
#  ['일렉트로룩스 ZB3302AK',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 14.4V / 4단계여과 / 충전시간: 4시간 / 사용시간: 42분 / 배터리: 리튬이온 / LED라이트 / 배터리잔량표시 / 브러쉬자동청소 / 셀프스탠딩 / 무게: 3.22kg / 알레르기인증(BAF) / 브러쉬: 바닥, 미니침구, 소파용, 긴틈새, 2in1 / 크기(가로x세로x깊이): 303x690x162mm',
#   '138730'],
#  ['샤오미 SHUNZAO 차량용 무선청소기 2세대 Z1 PRO (해외구매)',
#   '차량용청소기 / 무선 / 흡입력: 12,000Pa / 최대출력: 120W / 2중필터 / 추가노즐: 틈새, 솔브러쉬 / LED라이트 / 사용시간: 30분 / 충전시간: 2시간30분 / 충전방식: USB C타입 / 크기: 73x76x336mm / 무게: 610g',
#   '47390'],
#  ['일렉트로룩스 퓨어 Q9 PQ91-2OG',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 21.6V / 싸이클론 / 5단계여과 / 먼지통용량: 0.3L / 충전시간: 3시간30분 / 사용시간: 50분 / 배터리: 리튬이온 / 브러쉬: 바닥, 솔형, 틈새 / LED라이트 / 거치대 / 브러쉬자동청소 / 셀프스탠딩 / 무게: 2.7kg / 색상:그라나이트그레이 / 크기(가로x세로x깊이): 234x1056x163mm',
#   '260810'],
#  ['LG전자 코드제로 A9S A9470',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 헤파필터 / 2중터보싸이클론 / 5단계여과 / 인버터모터 / 흡입력: 200W / 충전시간: 4시간 / 사용시간: 2시간 / 배터리: 리튬이온 (2개) / 브러쉬: 바닥, 솔형, 틈새, 매트리스, 물걸레 / 거치대 / 디스플레이표시창 / 배터리잔량표시 / WiFi / 색상:아이언그레이 / 소비전력: 590W / 미세먼지인증(SLG) / 3단계물분사조절 / 크기(가로x세로x깊이): 250x1120x260mm',
#   '893210'],
#  ['LG전자 코드제로 A9S A9300',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 헤파필터 / 2중터보싸이클론 / 5단계여과 / 인버터모터 / 흡입력: 200W / 충전시간: 4시간 / 사용시간: 1시간 / 배터리: 리튬이온 / 브러쉬: 바닥, 솔형, 틈새, 매트리스 / 거치대 / 디스플레이표시창 / 배터리잔량표시 / WiFi / 색상:아이언그레이 / 소비전력: 590W / 미세먼지인증(SLG) / 크기(가로x세로x깊이): 250x1120x260mm',
#   '702020'],
#  ['삼성전자 제트 VS20T9278S3CS',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 21.9V / 헤파필터 / 싸이클론 / 5단계여과 / 인버터모터 / 흡입력: 200W / 먼지통용량: 0.5L / 충전시간: 3시간30분 / 사용시간: 2시간 / 배터리: 리튬이온 (2개) / 브러쉬: 바닥, 솔형, 틈새, 침구, 물걸레, 연장관 / 거치대 / 디스플레이표시창 / 프리볼트 / 색상:티탄실버 / 소비전력: 550W / 미세먼지인증(SLG) / 크기(가로x세로x깊이): 250x1136x215mm / [VCA-SAE90A] 청정스테이션 / 색상: 블랙 / 크기(가로x세로x깊이): 185x600x180mm',
#   '990450'],
#  ['삼성전자 제트 VS20R9078S2',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 21.9V / 헤파필터 / 싸이클론 / 5단계여과 / 인버터모터 / 흡입력: 200W / 먼지통용량: 0.5L / 충전시간: 3시간30분 / 사용시간: 120분 / 배터리: 리튬이온 (2개) / 브러쉬: 바닥, 솔형, 틈새, 침구, 물걸레, 연장관 / 거치대 / 디스플레이표시창 / 물걸레 / 프리볼트 / 무게: 2.7kg / 색상:티탄+블루 / 소비전력: 550W / 알레르기인증(BAF) / 미세먼지인증(SLG) / 크기(가로x세로x깊이): 250x1136x215mm',
#   '746510'],
#  ['다이슨 V11 컴플리트',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 싸이클론 / 흡입력: 185AW / 먼지통용량: 0.54L / 충전시간: 4시간30분 / 사용시간: 1시간 / 거치대 / 도킹스테이션 / 디스플레이표시창 / 무게: 2.95kg / 색상:니켈블루 / 브러쉬: 소프트롤러클리너헤드, 하이토크드라이브헤드, 콤비네이션툴, 크레비스툴, 미니모터툴, 소프트더스팅브러쉬, 매트리스툴, 스터번더트브러쉬 / 크기(가로x세로x깊이): 250x1280x261mm',
#   '720740'],
#  ['샤오미 SHUNZAO Z11 PRO',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 25.2V / 헤파필터 / 싸이클론 / 5단계여과 / 인버터모터 / 흡입력: 150AW / 흡입력: 26000Pa / 먼지통용량: 0.5L / 충전시간: 3시간 / 사용시간: 1시간 / 용량: 2500mAh / 브러쉬: 바닥, 솔형, 틈새, 침구, 연장관 / 거치대 / 디스플레이표시창 / 배터리잔량표시 / 색상:화이트, 레드',
#   '166240'],
#  ['샤오미 SHUNZAO 차량용 무선청소기 2세대 Z1 (해외구매)',
#   '차량용청소기 / 무선 / 흡입력: 7,000Pa / 최대출력: 90W / 2중필터 / 추가노즐: 틈새, 솔브러쉬 / LED라이트 / 사용시간: 30분 / 충전방식: USB C타입 / 충전시간: 2시간30분 / 크기: 73x76x336mm / 무게: 700g',
#   '25430'],
#  ['LG전자 코드제로 A9 A938',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 헤파필터 / 2중터보싸이클론 / 5단계여과 / 인버터모터 / 흡입력: 140W / 충전시간: 3시간30분 / 사용시간: 40분 / 배터리: 리튬이온 / 브러쉬: 바닥, 솔형, 틈새, 매트리스 / 거치대 / 무게: 2.7kg / 색상:판타지실버 / 소비전력: 450W / 크기(가로x세로x깊이): 260x1120x270mm',
#   '655000'],
#  ['LG전자 코드제로 A9S A9500',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 헤파필터 / 2중터보싸이클론 / 5단계여과 / 인버터모터 / 흡입력: 200W / 충전시간: 4시간 / 사용시간: 2시간 / 배터리: 리튬이온 (2개) / 브러쉬: 바닥, 솔형, 틈새, 침구, 매트리스 / 거치대 / 디스플레이표시창 / 배터리잔량표시 / WiFi / 색상:아이언그레이 / 소비전력: 590W / 미세먼지인증(SLG) / 크기(가로x세로x깊이): 250x1120x260mm',
#   '892870'],
#  ['삼성전자 제트 VS20R9043SA',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 21.9V / 헤파필터 / 싸이클론 / 5단계여과 / 인버터모터 / 흡입력: 200W / 먼지통용량: 0.5L / 충전시간: 3시간30분 / 사용시간: 60분 / 배터리: 리튬이온 / 브러쉬: 바닥, 솔형, 틈새, 연장관 / 거치대 / 디스플레이표시창 / 프리볼트 / 무게: 2.7kg / 색상:실버핑크 / 소비전력: 550W / 알레르기인증(BAF) / 미세먼지인증(SLG) / 크기(가로x세로x깊이): 250x1136x215mm',
#   '539000'],
#  ['카렉스 파워스톰 미니 무선청소기',
#   '차량용청소기 / 무선 / 흡입력: 12,000Pa / 2중필터 / 헤파필터 / 추가노즐: 틈새, 솔브러쉬 / 사용시간: 17분 / 충전방식: 시거잭, 220V / BLCD모터 / 충전시간: 5시간30분 / 크기: 93x439mm / 무게: 505g',
#   '80010'],
#  ['샤오미 WXCDJ01SWDK',
#   '물걸레청소기 / 스틱형 / 물걸레전용 / 왕복식 / 무선형 / 전압: 11.1V / 충전시간: 3시간 / 사용시간: 1시간 / 배터리: 리튬이온 / 용량: 2200mAh / 물분사 / LED라이트 / 각도조절 / 거치대 / 프리볼트 / 무게: 2.6kg / 소비전력: 25W / 색상:화이트 / 크기(가로x세로x깊이): 296x1114x220mm',
#   '80900'],
#  ['삼성전자 제트 VS20T9278S3',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 21.9V / 헤파필터 / 싸이클론 / 5단계여과 / 인버터모터 / 흡입력: 200W / 먼지통용량: 0.5L / 충전시간: 3시간30분 / 사용시간: 2시간 / 배터리: 리튬이온 (2개) / 브러쉬: 바닥, 솔형, 틈새, 침구, 물걸레, 연장관 / 거치대 / 디스플레이표시창 / 프리볼트 / 색상:티탄실버 / 소비전력: 550W / 미세먼지인증(SLG) / 크기(가로x세로x깊이): 250x1136x215mm',
#   '839020'],
#  ['다이슨 V11 220 에어와트 CF+',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 싸이클론 / 6단계여과 / 흡입력: 220AW / 먼지통용량: 0.54L / 충전시간: 4시간30분 / 사용시간: 60분 / 거치대 / 도킹스테이션 / 디스플레이표시창 / 무게: 2.95kg / 브러쉬: 소프트롤러클리너헤드, 하이토크클리너헤드, 콤비네이션툴, 크레비스툴, 미니모터툴, 미니소프트더스팅브러쉬, 매트리스툴, 스터번더트브러쉬 / 크기(가로x세로x깊이): 250x1280x261mm',
#   '864790'],
#  ['무궁화전자 바로바로 MC-B250',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 10.8V / 흡입력: 60W / 충전시간: 8시간 / 사용시간: 20분 / 배터리: 니켈수소 / 브러쉬: 바닥, 틈새, 연장관 / 거치대 / 무게: 1.3kg / 크기(가로x세로x깊이): 144x387x136mm',
#   '39750'],
#  ['일렉트로룩스 에르고라피도 프로 플러스 ZB3113AK',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 18V / 싸이클론 / 3단계여과 / 충전시간: 4시간 / 사용시간: 45분 / 배터리: 리튬이온 / LED라이트 / 배터리잔량표시 / 브러쉬자동청소 / 셀프스탠딩 / 무게: 2.6kg / 색상:텅스텐 / 브러쉬: 소파용, 연장호스, 긴틈새, 미니침구 / 크기(가로x세로x깊이): 263x1070x150mm',
#   '169000'],
#  ['DIBEA DW200',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 22.2V / 싸이클론 / 4단계여과 / 흡입력: 10000Pa / 먼지통용량: 0.5L / 충전시간: 4~5시간 / 사용시간: 35분 / 배터리: 리튬이온 / 용량: 2200mAh / 브러쉬: 바닥, 솔형, 틈새, 연장관 / 무게: 2kg / 색상:화이트 / 소비전력: 150W / 100V / 변환어댑터: 필요 / 크기(가로x세로x깊이): 210x1040x104mm',
#   '71230'],
#  ['삼성전자 뉴파워건 130',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 32.4V / 헤파필터 / 싸이클론 / 5단계여과 / 인버터모터 / 흡입력: 130W / 충전시간: 4시간30분 / 사용시간: 40분 / 배터리: 리튬이온 / 브러쉬: 바닥, 솔형, 틈새 / 무게: 2.95kg / 색상:에어본블랙 / 소비전력: 400W / 플렉스핸들 / 크기(가로x세로x깊이): 252x1110x315mm',
#   '340090'],
#  ['휴스톰 HS-9000',
#   '물걸레청소기 / 스틱형 / 물걸레전용 / 회전식 / 무선형 / 전압: 14.6V / 충전시간: 4시간 / 사용시간: 30분 / 배터리: 리튬이온 / 용량: 2850mAh / LED라이트 / 가구손상방지 / 각도조절 / 셀프스탠딩 / 무게: 3.6kg / 색상:블랙 / 모터과열방지 / 과충전방지 / 오토스토핑 / 패드: 극세사(벨크로형) / 크기(가로x세로x깊이): 410x860x256mm',
#   '134930'],
#  ['삼성전자 제트 VS20T9279S6CS',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 21.9V / 헤파필터 / 싸이클론 / 5단계여과 / 인버터모터 / 흡입력: 200W / 먼지통용량: 0.5L / 충전시간: 3시간30분 / 사용시간: 2시간 / 배터리: 리튬이온 (2개) / 브러쉬: 바닥, 솔형, 틈새, 펫, 물걸레, 연장관 / 거치대 / 디스플레이표시창 / 프리볼트 / 색상:티탄블루 / 소비전력: 550W / 미세먼지인증(SLG) / 크기(가로x세로x깊이): 250x1136x215mm / [VCA-SAE90A] 청정스테이션 / 색상: 블랙 / 크기(가로x세로x깊이): 185x600x180mm',
#   '971660'],
#  ['다이슨 V10 카본파이버',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 25.2V / 싸이클론 / 흡입력: 160AW / 충전시간: 3시간30분 / 사용시간: 60분 / 배터리: 리튬이온 / 도킹스테이션 / 무게: 2.5kg / 소비전력: 525W / 브러쉬: 소프트롤러헤드, 토크드라이브클리너헤드, 콤비네이션툴, 크레비스툴, 미니모터툴, 플렉시크레비스툴, 소프트더스팅브러시, 연장호스 / 크기(가로x세로x깊이): 250x1241x256mm',
#   '653140'],
#  ['일렉트로룩스 에르고라피도 파워프로 ZB3411',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 18V / 헤파필터 / 4단계여과 / 먼지통용량: 0.42L / 충전시간: 4시간 / 사용시간: 48분 / 배터리: 리튬이온 / 거치대 / 배터리잔량표시 / 셀프스탠딩 / 무게: 3kg / 색상:타이탄블루 / 브러쉬: 파워프로롤러, UV베드, 틈새 / 크기(가로x세로x깊이): 303x690x162mm',
#   '193310'],
#  ['ABKO 오엘라 네오스핀 OBC-AW09WH',
#   '핸디/스틱청소기 / 스틱형 / 무선형 / 전압: 3.7V / 충전시간: 4~5시간 / 사용시간: 50분 / 배터리: 리튬이온 / 용량: 1950mAh / 무게: 0.86kg / 소비전력: 8W / 생활방수 / 브러쉬: 원형, 평면, 틈새',
#   '53810'],
#  ['삼성전자 제트 VS20R9078S3',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 21.9V / 헤파필터 / 싸이클론 / 5단계여과 / 인버터모터 / 흡입력: 200W / 먼지통용량: 0.5L / 충전시간: 3시간30분 / 사용시간: 120분 / 배터리: 리튬이온 (2개) / 브러쉬: 바닥, 솔형, 틈새, 침구, 물걸레, 연장관 / 거치대 / 디스플레이표시창 / 물걸레 / 프리볼트 / 무게: 2.7kg / 색상:티탄+그레이 / 소비전력: 550W / 알레르기인증(BAF) / 미세먼지인증(SLG) / 크기(가로x세로x깊이): 250x1136x215mm',
#   '798990'],
#  ['LG전자 코드제로 A9S A9370',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 헤파필터 / 2중터보싸이클론 / 5단계여과 / 인버터모터 / 흡입력: 200W / 충전시간: 4시간 / 사용시간: 1시간 / 배터리: 리튬이온 / 브러쉬: 바닥, 솔형, 틈새, 물걸레 / 거치대 / 디스플레이표시창 / 배터리잔량표시 / WiFi / 색상:판타지실버 / 소비전력: 590W / 미세먼지인증(SLG) / 3단계물분사조절 / 크기(가로x세로x깊이): 250x1120x260mm',
#   '819690'],
#  ['DIBEA D18',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 22.2V / 헤파필터 / H13급 / 싸이클론 / 3단계여과 / 흡입력: 9000Pa / 먼지통용량: 0.55L / 충전시간: 4~5시간 / 사용시간: 45분 / 배터리: 리튬이온 / 용량: 2200mAh / 브러쉬: 바닥, 솔형, 틈새, 연장관 / LED라이트 / 거치대 / 배터리잔량표시 / 프리볼트 / 무게: 2.2kg / 소비전력: 120W / 크기(가로x세로x깊이): 240x1040x210mm',
#   '88220'],
#  ['휴스톰 HS-10000',
#   '물걸레청소기 / 스틱형 / 물걸레전용 / 회전식 / 무선형 / 전압: 14.6V / 충전시간: 2시간30분 / 사용시간: 30분 / 배터리: 리튬이온 / 용량: 2750mAh / LED라이트 / 가구손상방지 / 각도조절 / 셀프스탠딩 / 배터리잔량표시 / 프리볼트 / 무게: 3.7kg / 색상:블랙 / 모터과열방지 / 과충전방지 / 오토스토핑 / 패드: 극세사(벨크로형) / 크기(가로x세로x깊이): 410x1180x205mm',
#   '148860'],
#  ['샤오미 드리미 V9',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 25.2V / 헤파필터 / 싸이클론 / 5단계여과 / 흡입력: 120AW / 흡입력: 20000Pa / 먼지통용량: 0.5L / 충전시간: 3시간30분 / 사용시간: 60분 / 용량: 2500mAh / 브러쉬: 바닥, 솔형, 틈새, 침구, 연장관 / 거치대 / 무게: 1.5kg / 색상:화이트 / 소비전력: 400W',
#   '298000'],
#  ['혼스 차량 무선 진공 청소기 HSCC-8000',
#   '차량용청소기 / 무선 / 흡입력: 8,000Pa / 최대출력: 150W / 헤파필터 / 추가노즐: 틈새, 솔브러쉬 / 색상 : 핑크, 브라운, 그레이, 화이트 / 크기 : 191x111x65mm / 무게 : 650g',
#   '56050'],
#  ['삼성전자 제트 VS20T9278S7CS',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 21.9V / 헤파필터 / 싸이클론 / 5단계여과 / 인버터모터 / 흡입력: 200W / 먼지통용량: 0.5L / 충전시간: 3시간30분 / 사용시간: 2시간 / 배터리: 리튬이온 (2개) / 브러쉬: 바닥, 솔형, 틈새, 침구, 물걸레, 연장관 / 거치대 / 디스플레이표시창 / 프리볼트 / 색상:티탄골드 / 소비전력: 550W / 미세먼지인증(SLG) / 크기(가로x세로x깊이): 250x1136x215mm / [VCA-SAE90A] 청정스테이션 / 색상: 블랙 / 크기(가로x세로x깊이): 185x600x180mm',
#   '1062480'],
#  ['샤오미 SHUNZAO Z11',
#   '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 25.2V / 헤파필터 / 싸이클론 / 5단계여과 / 흡입력: 150AW / 흡입력: 26000Pa / 먼지통용량: 0.5L / 충전시간: 3시간 / 사용시간: 1시간 / 배터리: 리튬이온 / 용량: 2500mAh / 브러쉬: 바닥, 솔형, 틈새, 침구, 연장관 / 거치대 / 디스플레이표시창 / 배터리잔량표시 / 색상:화이트',
#   '154990'],
#  ['진공 청소기 유선 1개, 무선 1개', '', '1000']]

# %%
#페이지 검색 결과에 대해 상품 정보 추출하는 함수
def get_prod_items(prod_items):
    prod_data=[]
    for prod_item in prod_items:
        #상품명
        try:
            title=prod_item.select("p.prod_name > a")[0].text.strip()
        except:
            title=""
        #스펙리스트
        try:
            spec_list=prod_item.select("div.spec_list")[0].text.strip()
        #가격정보
        except:
            spec_list=""
        try:
            price=prod_item.select("p.price_sect > a > strong")[0].text.strip().replace(",","")
        except:
            price=0
        prod_data.append([title, spec_list, price])
    return prod_data

# %%
prod_items=soup.select("div.main_prodlist > ul.product_list > li.prod_item")
prod_data=get_prod_items(prod_items)
print(prod_data)
# Out:
# [['델로라 V11 파워 300W', '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압:
'핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 헤파필터 / 2중터보싸이클론 / 5단계여과 / 인버터모터 / 흡입력: 200W / 충전시간: 4시간 / 사용시간: 1시간 / 배터리: 리튬이온 / 브러쉬: 바닥, 솔형, 틈새, 매트리스 / 거치대 / 디스플레이표시창 / 배터리잔량표시 / WiFi / 색상:아이언그레이 / 소비전력: 590W / 미세먼지인증(SLG) / 크기(가로x세로x깊이): 250x1120x260mm', '702020'], ['삼성전자 제트 VS20T9278S3CS', '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 21.9V / 헤파필터 / 싸이클론 / 5단계여과 / 인버터모터 / 흡입력: 200W / 먼지통용량: 0.5L / 충전시간: 3시간30분 / 사용시간: 2시간 / 배터리: 리튬이온 (2개) / 브러쉬: 바닥, 솔형, 틈새, 침구, 물걸레, 연장관 / 거치대 / 디스플레이표시창 / 프리볼트 / 색상:티탄실버 / 소비전력: 550W / 미세먼지인증(SLG) / 크기(가로x세로x깊이): 250x1136x215mm / [VCA-SAE90A] 청정스테이션 / 색상: 블랙 / 크기(가로x세로x깊이): 185x600x180mm', '990450'], ['삼성전자 제트 VS20R9078S2', '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 21.9V / 헤파필터 / 싸이클론 / 5단계여과 / 인버터모터 / 흡입력: 200W / 먼지통용량: 0.5L / 충전시간: 3시간30분 / 사용시간: 120분 / 배터리: 리튬이온 (2개) / 브러쉬: 바닥, 솔형, 틈새, 침구, 물걸레, 연장관 / 거치대 / 디스플레이표시창 / 물걸레 / 프리볼트 / 무게: 2.7kg / 색상:티탄+블루 / 소비전력: 550W / 알레르기인증(BAF) / 미세먼지인증(SLG) / 크기(가로x세로x깊이): 250x1136x215mm', '746510'], ['다이슨 V11 컴플리트', '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 싸이클론 / 흡입력: 185AW / 먼지통용량: 0.54L / 충전시간: 4시간30분 / 사용시간: 1시간 / 거치대 / 도킹스테이션 / 디스플레이표시창 / 무게: 2.95kg / 색상:니켈블루 / 브러쉬: 소프트롤러클리너헤드, 하이토크드라이브헤드, 콤비네이션툴, 크레비스툴, 미니모터툴, 소프트더스팅브러쉬, 매트리스툴, 스터번더트브러쉬 / 크기(가로x세로x깊이): 250x1280x261mm', '720740'], ['샤오미 SHUNZAO Z11 PRO', '핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 25.2V / 헤파필터 / 싸이클론 / 5단계여과 / 인버터모터 / 흡입력: 150AW / 흡입력: 26000Pa / 먼지통용량: 0.5L / 충전시간: 3시간 / 사용시간: 1시간 / 용량: 2500mAh / 브러쉬: 바닥, 솔형, 틈새, 침구, 연장관 / 거치대 / 디스플레이표시창 / 배터리잔량표시 / 색상:화이트, 레드', '166240'], ['샤오미 SHUNZAO ...

# %%
#http://search.danawa.com/dsearch.php?query=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&originalQuery=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&previousKeyword=%EB%AC%B4%EC%84%A0%EC%B2%AD%EC%86%8C%EA%B8%B0&volumeType=allvs&page=2&limit=40&sort=saveDESC&list=list&boost=true&addDelivery=N&tab=goods
#다나와 무선청소기 검색 결과(2page)

def get_search_page_url(keyword, page):
    return "http://search.danawa.com/dsearch.php?query={}&volumeType=allvs&page={}&limit=40&sort=saveDESC&list=list&boost=true&addDelivery=N&tab=goods".format(keyword,page)
keyword="무선충전기"
page=5
url=get_search_page_url(keyword, page)
print(url)
# Out:
# http://search.danawa.com/dsearch.php?query=무선충전기&volumeType=allvs&page=5&limit=40&sort=saveDESC&list=list&boost=true&addDelivery=N&tab=goods

# %%
#pip install tqdm
import time
from tqdm import tqdm_notebook
#진행 상황 출력

# %%
t=10
for p in tqdm_notebook(range(1,t+1)):
    time.sleep(5)
# Out:
# <ipython-input-65-94836e0950cd>:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for p in tqdm_notebook(range(1,t+1)):
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %%
#여러 페이지에 걸쳐 검색 결과 정보 추출

# %%
keyword="무선청소기"
total_page=10
prod_data_total=[]

#진행 상황 출력
for page in tqdm_notebook(range(1,total_page+1)):
    #검색 페이지 이동
    url=get_search_page_url(keyword, page)
    driver.get(url)
    #페이지가 완전히 로딩될때까지 소요되는 시간을 최대 3초로 가정
    time.sleep(3)
    
    #현재 페이지 html 문서 가져오기
    html=driver.page_source
    soup=BeautifulSoup(html, 'html.parser')
    
    #상품 정보 추출
    prod_items=soup.select("div.main_prodlist > ul.product_list > li.prod_item")
    prod_item_list=get_prod_items(prod_items)
    
    #추출 정보 저장
    prod_data_total=prod_data_total+prod_item_list
# Out:
# <ipython-input-68-161bf4963798>:6: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for page in tqdm_notebook(range(1,total_page+1)):
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %%
prod_data_total[399]
# Out:
# ['신일산업 SVC-G60YHJ',
#  '핸디/스틱청소기 / 핸디+스틱형 / 유선형 / 헤파필터 / 브러쉬: 틈새 / 색상:블루, 실버, 골드 / 소비전력: 400W / 크기(가로x세로x깊이): 185x170x580mm',
#  '45920']

# %%
import pandas as pd

# %%
data=pd.DataFrame(prod_data_total)
data.columns=['상품명', '스펙 목록', '가격']
data
# Out:
#                            상품명  \
# 0              델로라 V11 파워 300W
# 1    샤오미 차량용 청소기 무선 3세대 (해외구매)
# 2          LG전자 코드제로 A9S A9700
# 3                   다이슨 V8 플러피
# 4          LG전자 코드제로 A9S A9570
# ..                         ...
# 395                 idam 701B1
# 396              테팔 에어포스 TY846
# 397             아로나전자 AL-6200R
# 398                스마트에버 S250W
# 399            신일산업 SVC-G60YHJ
#
#                                                  스펙 목록       가격
# 0    핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 29.6V / 헤파필터 / 싸...   135330
# 1    차량용청소기 / 무선 / 흡입력: 16,800Pa / 헤파필터 / 추가노즐: 틈새,...    58790
# 2    핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 헤파필터 / 2중터보싸이클론 / 5단...  1022240
# 3    핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 21.6V / 싸이클론 / 흡...   456500
# 4    핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 헤파필터 / 2중터보싸이클론 / 5단...   954710
# ..                                                 ...      ...
# 395        핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 브러쉬: 바닥 / 색상:연그레이    38990
# 396  핸디/스틱청소기 / 스틱형 / 무선형 / 전압: 12V / 싸이클론 / 충전시간: ...   214840
# 397  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 충전시간: 8시간충전 / 사용시간: ...    51520
# 398  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 22.2V / 헤파필터 / H...   119000
# 399  핸디/스틱청소기 / 핸디+스틱형 / 유선형 / 헤파필터 / 브러쉬: 틈새 / 색상:...    45920
#
# [400 rows x 3 columns]

# %%
data.to_excel("danawa_crawling_result.xlsx", index=False)

# %%
data=pd.read_excel("danawa_crawling_result.xlsx")
data
# Out:
#                            상품명  \
# 0              델로라 V11 파워 300W
# 1    샤오미 차량용 청소기 무선 3세대 (해외구매)
# 2          LG전자 코드제로 A9S A9700
# 3                   다이슨 V8 플러피
# 4          LG전자 코드제로 A9S A9570
# ..                         ...
# 395                 idam 701B1
# 396              테팔 에어포스 TY846
# 397             아로나전자 AL-6200R
# 398                스마트에버 S250W
# 399            신일산업 SVC-G60YHJ
#
#                                                  스펙 목록       가격
# 0    핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 29.6V / 헤파필터 / 싸...   135330
# 1    차량용청소기 / 무선 / 흡입력: 16,800Pa / 헤파필터 / 추가노즐: 틈새,...    58790
# 2    핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 헤파필터 / 2중터보싸이클론 / 5단...  1022240
# 3    핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 21.6V / 싸이클론 / 흡...   456500
# 4    핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 헤파필터 / 2중터보싸이클론 / 5단...   954710
# ..                                                 ...      ...
# 395        핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 브러쉬: 바닥 / 색상:연그레이    38990
# 396  핸디/스틱청소기 / 스틱형 / 무선형 / 전압: 12V / 싸이클론 / 충전시간: ...   214840
# 397  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 충전시간: 8시간충전 / 사용시간: ...    51520
# 398  핸디/스틱청소기 / 핸디+스틱형 / 무선형 / 전압: 22.2V / 헤파필터 / H...   119000
# 399  핸디/스틱청소기 / 핸디+스틱형 / 유선형 / 헤파필터 / 브러쉬: 틈새 / 색상:...    45920
#
# [400 rows x 3 columns]

# %%
#상품명 -> 회사명 + 모델명

# %%
company_list=[]
product_list=[]
for title in data['상품명']:
    title_info=title.split(" ",1)
    company_name=title_info[0]
    company_list.append(company_name)
    product_name=title_info[1]
    product_list.append(product_name)

# %%
#product_list

# %%
spec_list=data['스펙 목록'][0].split(" / ")

# %%
category=spec_list[0]

# %%
for spec in spec_list:
    if '사용시간' in spec: #spec변수에 있는 문자열이 '사용시간'을 포함하고 있다면
        use_time_spec=spec
    elif '흡입력' in spec:
        suction_spec=spec
print(use_time_spec)
print(suction_spec)        
    #print(spec)
#'사용시간: 1시간10분' 출력
#도메인 지식(domain knowledge)
# Out:
# 사용시간: 1시간10분
# 흡입력: 22000Pa

# %%
use_time_value=use_time_spec.split(" ")[1].strip()
suction_value=suction_spec.split(" ")[1].strip()
# 1시간10분
#suction_spec
# 22000Pa

# %%
category_list=[] #[핸디/스틱청소기, 차량용청소기...]
use_time_list=[] #[1시간10분, 25분...]
suction_list=[] #[22000Pa, 16,800Pa...]
for spec_data in data['스펙 목록']:
    spec_list=spec_data.split(" / ")
    category=spec_list[0]
    category_list.append(category)
    for spec in spec_list:
        if '사용시간' in spec: #spec변수에 있는 문자열이 '사용시간'을 포함하고 있다면
            use_time_value=spec.split(" ")[1].strip()
        elif '흡입력' in spec:
            suction_value=spec.split(" ")[1].strip()
    use_time_list.append(use_time_value)
    suction_list.append(suction_value)
    
print(category_list)
print("="*50)
print(use_time_list)
print("="*50)
print(suction_list)
# Out:
# ['핸디/스틱청소기', '차량용청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '차량용청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '차량용청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '차량용청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '핸디/스틱청소기', '차량용청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '차량용청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '핸디/스틱청소기', '로봇청소기', '핸디/스틱청소기', '물걸레청소기', '침구청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '물걸레청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '진공청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '업소용청소기', '핸디/스틱청소기', '차량용청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '물걸레청소기', '차량용청소기', '핸디/스틱청소기', '핸디/스틱청소기', '업소용청소기', '물걸레청소기', '핸디/스틱청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '차량용청소기', '핸디/스틱청소기', '핸디/스틱청소기', '차량용청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '차량용청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '업소용청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '업소용청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '차량용청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '차량용청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '업소용청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '차량용청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '업소용청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '차량용청소기', '핸디/스틱청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '차량용청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '차량용청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '물걸레청소기', '핸디/스틱청소기', '진공청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', '핸디/스틱청소기', ' ...
# ==================================================
# ['1시간10분', '25분', '2시간', '40분', '2시간', '1시간', '42분', '30분', '50분', '2시간', '1시간', '2시간', '120분', '1시간', '1시간', '30분', '40분', '2시간', '60분', '17분', '1시간', '2시간', '60분', '20분', '45분', '35분', '40분', '30분', '2시간', '60분', '48분', '50분', '120분', '1시간', '45분', '30분', '60분', '60분', '2시간', '1시간', '30분', '42분', '40분', '1시간20분', '23분', '2시간', '60분', '50분', '45분', '1시간30분', '80분', '35분', '30분', '40분', '30분', '12분', '48분', '45분', '9분', '1시간', '2시간', '20분', '1시간20분', '1시간20분', '40분', '80분', '30분', '20분', '1시간', '55분', '1시간5분', '40분', '40분', '40분', '30분', '1시간', '1시간', '40분', '30분', '40분', '40분', '40분', '80분', '3시간', '40분(강),', '20분', '25분', '25분', '60분', '30분', '40분', '12~30분', '40분', '60분', '50분', '40분', '80분', '1시간', '55분', '50분', '30분', '30분', '30분', '60분', '40분', '40분', '80분', '30분', '45분', '40분', '40분', '40분', '30분', '30분', '40분',
W', '250W', '35W', '9000Pa', '9000Pa', '10000Pa', '9000Pa', '200W', '200W', '5900Pa', '5900Pa', '200W', '35W', '35W', '35W', '35W', '12000Pa', '150W', '150W', '200W', '200W', '200W', '200W', '5500Pa', '5500Pa', '20000Pa', '5,500Pa', '11000Pa', '70W', '8000Pa', '8000Pa', '8000Pa', '2000Pa', '20000Pa', '20000Pa', '20000Pa', '13.8W', '13.8W', '13.8W', '18000Pa', '18000Pa', '21000Pa', '21000Pa', '100AW', '20000Pa', '20000Pa', '25AW', '25AW', '25AW', '25AW', '25AW', '140W', '140W', '140W', '140W', '140W', '140W', '140W', '7200Pa', '200W', '200W', '200W', '8000Pa', '35W', '35W', '35W', '35W', '20000Pa', '20000Pa']

# %%
#1. 사용시간을 분 단위로 조정하는 함수를 구현
# 40분 => 40
# 4시간 => 240
# 2시간30분 => 150

# %%
def convert_time_minute(time): #"40분"
    try:
        # 코드 완성
        if '시간' in time:
            hour=time.split("시간")[0]
            if '분' in time:
                minute=time.split('시간')[-1].split('분')[0]
            else:
                minute=0
        else:
            hour=0
            minute=time.split("분")[0]
        return int(hour)*60+int(minute)  
    except:
        return None

times=["40분","4분","1시간","3시간30분"]
for time in times:
    time_value=convert_time_minute(time)
    print(time, "=", time_value)
# Out:
# 40분 = 40
# 4분 = 4
# 1시간 = 60
# 3시간30분 = 210

# %%
int("60")*2
# Out:
# 120

# %%
new_use_time_list=[]
for time in use_time_list:
    value=convert_time_minute(time)
    new_use_time_list.append(value)

# %%
new_use_time_list
# Out:
# [70,
#  25,
#  120,
#  40,
#  120,
#  60,
#  42,
#  30,
#  50,
#  120,
#  60,
#  120,
#  120,
#  60,
#  60,
#  30,
#  40,
#  120,
#  60,
#  17,
#  60,
#  120,
#  60,
#  20,
#  45,
#  35,
#  40,
#  30,
#  120,
#  60,
#  48,
#  50,
#  120,
#  60,
#  45,
#  30,
#  60,
#  60,
#  120,
#  60,
#  30,
#  42,
#  40,
#  80,
#  23,
#  120,
#  60,
#  50,
#  45,
#  90,
#  80,
#  35,
#  30,
#  40,
#  30,
#  12,
#  48,
#  45,
#  9,
#  60,
#  120,
#  20,
#  80,
#  80,
#  40,
#  80,
#  30,
#  20,
#  60,
#  55,
#  65,
#  40,
#  40,
#  40,
#  30,
#  60,
#  60,
#  40,
#  30,
#  40,
#  40,
#  40,
#  80,
#  180,
#  40,
#  20,
#  25,
#  25,
#  60,
#  30,
#  40,
#  None,
#  40,
#  60,
#  50,
#  40,
#  80,
#  60,
#  55,
#  50,
#  30,
#  30,
#  30,
#  60,
#  40,
#  40,
#  80,
#  30,
#  45,
#  40,
#  40,
#  40,
#  30,
#  30,
#  40,
#  80,
#  30,
#  40,
#  40,
#  40,
#  60,
#  90,
#  40,
#  120,
#  45,
#  40,
#  None,
#  10,
#  20,
#  40,
#  40,
#  60,
#  30,
#  300,
#  40,
#  60,
#  60,
#  12,
#  30,
#  60,
#  35,
#  30,
#  42,
#  12,
#  55,
#  100,
#  50,
#  50,
#  35,
#  24,
#  30,
#  24,
#  9,
#  25,
#  25,
#  9,
#  48,
#  30,
#  45,
#  20,
#  14,
#  53,
#  53,
#  40,
#  5,
#  30,
#  80,
#  80,
#  40,
#  15,
#  30,
#  60,
#  53,
#  25,
#  15,
#  55,
#  50,
#  25,
#  30,
#  48,
#  20,
#  120,
#  13,
#  22,
#  15,
#  30,
#  30,
#  20,
#  40,
#  53,
#  40,
#  30,
#  60,
#  12,
#  50,
#  80,
#  20,
#  60,
#  40,
#  48,
#  35,
#  60,
#  60,
#  11,
#  80,
#  30,
#  40,
#  35,
#  90,
#  60,
#  25,
#  None,
#  16,
#  40,
#  80,
#  60,
#  None,
#  40,
#  120,
#  30,
#  35,
#  120,
#  120,
#  60,
#  60,
#  30,
#  25,
#  60,
#  35,
#  20,
#  16,
#  30,
#  40,
#  12,
#  45,
#  12,
#  45,
#  60,
#  20,
#  80,
#  30,
#  60,
#  30,
#  23,
#  24,
#  60,
#  30,
#  66,
#  30,
#  12,
#  30,
#  30,
#  30,
#  30,
#  48,
#  25,
#  60,
#  30,
#  30,
#  20,
#  30,
#  30,
#  40,
#  40,
#  40,
#  None,
#  40,
#  30,
#  15,
#  60,
#  20,
#  20,
#  35,
#  18,
#  18,
#  18,
#  50,
#  30,
#  35,
#  30,
#  35,
#  None,
#  15,
#  15,
#  30,
#  40,
#  40,
#  70,
#  30,
#  20,
#  12,
#  12,
#  None,
#  48,
#  55,
#  50,
#  60,
#  None,
#  45,
#  9,
#  25,
#  25,
#  100,
#  48,
#  35,
#  45,
#  40,
#  40,
#  23,
#  15,
#  None,
#  None,
#  25,
#  35,
#  40,
#  30,
#  60,
#  40,
#  60,
#  40,
#  30,
#  30,
#  60,
#  120,
#  35,
#  20,
#  20,
#  20,
#  8,
#  8,
#  40,
#  35,
#  40,
#  15,
#  35,
#  30,
#  50,
#  35,
#  120,
#  120,
#  15,
#  15,
#  120,
#  None,
#  None,
#  40,
#  35,
#  35,
#  20,
#  7,
#  120,
#  40,
#  30,
#  12,
#  30,
#  60,
#  35,
#  20,
#  40,
#  40,
#  45,
#  40,
#  120,
#  20,
#  35,
#  40,
#  40,
#  12,
#  25,
#  40,
#  35,
#  10,
#  60,
#  65,
#  30,
#  45,
#  25,
#  17,
#  17,
#  30,
#  14,
#  40,
#  90,
#  90,
#  30,
#  48,
#  None,
#  None,
#  100,
#  25,
#  60,
#  50,
#  30,
#  40,
#  None,
#  None,
#  25,
#  None,
#  25,
#  25]

# %%
df=pd.DataFrame()
df['카테고리']=category_list
df['회사명']=company_list
df['제품']=product_list
df['가격']=data['가격']
df['사용시간']=new_use_time_list
df.head()
# Out:
#        카테고리   회사명                     제품       가격   사용시간
# 0  핸디/스틱청소기   델로라            V11 파워 300W   135330   70.0
# 1    차량용청소기   샤오미  차량용 청소기 무선 3세대 (해외구매)    58790   25.0
# 2  핸디/스틱청소기  LG전자         코드제로 A9S A9700  1022240  120.0
# 3  핸디/스틱청소기   다이슨                 V8 플러피   456500   40.0
# 4  핸디/스틱청소기  LG전자         코드제로 A9S A9570   954710  120.0
