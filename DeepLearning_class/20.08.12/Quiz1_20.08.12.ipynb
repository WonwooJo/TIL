# %% [markdown]
# ### 보배드림 데이터 프레임 >> 저장
# #### - 차량명 인승 마력 연식 연료 주행거리 가격
# ##### - https://www.bobaedream.co.kr/cyber/CyberCar.php?gubun=K&page=1&order=S11&view_size=50
# #### - 100대

# %%
#### 차량명                     인승  마력   연식    연료  주행거리  가격
#### 현대그랜져 HG300 LPG 모던   5     235  15/11    LPG   20만km  880 만원

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from tqdm import tqdm_notebook
import time
driver = webdriver.Chrome('c:/mychrome/chromedriver.exe')

# %%
prod_data_total = []
for page in tqdm_notebook(range(1,3)):
    url = 'https://www.bobaedream.co.kr/cyber/CyberCar.php?gubun=K&page={}&order=S11&view_size=50'.format(page)
    # 검색 페이지로 이동
    driver.get(url)
    
    # 페이지가 완전히 로딩될 때까지 소요되는 시간 3초로 가정.
    time.sleep(3) # 실제 페이지를 완전히 읽을 때 까지 걸리는 시간을 고려해서 진행 바람.

    # 현재 페이지 html문서 가져오기
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')

    # 상품 정보 추출
    # prod_titles = soup.select('p.tit ellipsis > a')[0].string.strip() 
    prod_people = soup.select('dd.data-item > a')[0].string.strip() # OK
    prod_force = soup.select('div.mode-cell.title > dl > dd:nth-child(4)')[0].string.strip()
    # prod_year = soup.select('div.mode-cell.year > span')[0].string.strip()
    prod_fuel = soup.select('div.mode-cell.fuel > span')[0].string.strip()
    prod_distance = soup.select('div.mode-cell.km > span')[0].string.strip()
    prod_price = soup.select('strong.price-whole.cr')[0].string.strip()
    prod_data_total.append([prod_titles, prod_people, prod_force, prod_year, prod_fuel, prod_distance, prod_price])
# Out:
# <ipython-input-28-31826a7a0c43>:2: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for page in tqdm_notebook(range(1,3)):
# ...

# %%
len(soup.select('dd.data-item > a'))
# Out:
# 52

# %%
prod_data_total
# Out:
# [[[],
#   '9인승',
#   '280마력',
#   [<span class="text">09/03</span>,
#    <span class="text">18/12<br/>(19년형)</span>,
#    <span class="text">18/04<br/>(19년형)</span>,
#    <span class="text">09/05</span>,
#    <span class="text">14/07<br/>(15년형)</span>,
#    <span class="text">16/08</span>,
#    <span class="text">13/03</span>,
#    <span class="text">10/03</span>,
#    <span class="text">14/05</span>,
#    <span class="text">10/12<br/>(11년형)</span>,
#    <span class="text">10/01</span>,
#    <span class="text">17/05</span>,
#    <span class="text">14/09<br/>(15년형)</span>,
#    <span class="text">04/08</span>,
#    <span class="text">16/01</span>,
#    <span class="text">15/07</span>,
#    <span class="text">17/05</span>,
#    <span class="text">15/06<br/>(16년형)</span>,
#    <span class="text">11/08<br/>(12년형)</span>,
#    <span class="text">08/11<br/>(09년형)</span>,
#    <span class="text">12/12</span>,
#    <span class="text">10/08<br/>(11년형)</span>,
# ...
