# %%
from datetime import datetime # datetime모듈에 있는 datetime이라는 객체를 가져와라
'''
패키지(폴더, 서브패키지를 포함) 


import 패키지명.서브패키지명

'''
import pandas as pd

# %%
ebola = pd.read_csv('data/country_timeseries.csv')

# %%
df2 = pd.DataFrame({'order_day':['01-01-20','01-02-20']}) # 월-일-년 형식
df.info()
df2['date_dt'] = pd.to_datetime(df2['order_day']) # 년-월-일 형식
print(df2)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
df2['date_dt2'] = pd.to_datetime(df2['order_day'], format='%d-%m-%y') # 일-월-년 형식
df2
# Out:
#   order_day    date_dt   date_dt2
# 0  01-01-20 2020-01-01 2020-01-01
# 1  01-02-20 2020-01-02 2020-02-01

# %%
now = datetime.now()
now
# Out:
# datetime.datetime(2020, 9, 11, 10, 11, 14, 568660)

# %%
nowDate = now.strftime('%H:%M:%S')
nowDate
# Out:
# '10:11:14'

# %%
now.strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2020-09-11 10:11:14'

# %%
# 읽을 때 부터 한 컬럼을 Datetime으로 읽어라
ebola2 = pd.read_csv('data/country_timeseries.csv',parse_dates=['Date'])
ebola2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    datetime64[ns]
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
d1 = ebola2['Date']
d1
# Out:
# 0     2015-01-05
# 1     2015-01-04
# 2     2015-01-03
# 3     2015-01-02
# 4     2014-12-31
#          ...
# 117   2014-03-27
# 118   2014-03-26
# 119   2014-03-25
# 120   2014-03-24
# 121   2014-03-22
# Name: Date, Length: 122, dtype: datetime64[ns]

# %%
print(d1[0].year)
print(d1[0].month)
print(d1[0].day)
# Out:
# 2015
# 1
# 5

# %%
ebola3 = pd.read_csv('data/country_timeseries.csv')
ebola3.info()
ebola3['Date_dt'] = pd.to_datetime(ebola3['Date'])
ebola3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 122 entries, 0 to 121
# Data columns (total 18 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 122 non-null    object
#  1   Day                  122 non-null    int64
#  2   Cases_Guinea         93 non-null     float64
#  3   Cases_Liberia        83 non-null     float64
#  4   Cases_SierraLeone    87 non-null     float64
#  5   Cases_Nigeria        38 non-null     float64
#  6   Cases_Senegal        25 non-null     float64
#  7   Cases_UnitedStates   18 non-null     float64
#  8   Cases_Spain          16 non-null     float64
#  9   Cases_Mali           12 non-null     float64
#  10  Deaths_Guinea        92 non-null     float64
#  11  Deaths_Liberia       81 non-null     float64
#  12  Deaths_SierraLeone   87 non-null     float64
#  13  Deaths_Nigeria       38 non-null     float64
#  14  Deaths_Senegal       22 non-null     float64
# ...

# %%
ebola3['Date_dt'][0]
# Out:
# Timestamp('2015-01-05 00:00:00')

# %%
ebola3['Date_dt'].dt.year # year을 모조리 뽑아오는 방법(for문 안돌리고) / 문자열은 .str.~~
# Out:
# 0      2015
# 1      2015
# 2      2015
# 3      2015
# 4      2014
#        ...
# 117    2014
# 118    2014
# 119    2014
# 120    2014
# 121    2014
# Name: Date_dt, Length: 122, dtype: int64

# %%
ebola3['Date_dt'].dt.month
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4      12
#        ..
# 117     3
# 118     3
# 119     3
# 120     3
# 121     3
# Name: Date_dt, Length: 122, dtype: int64

# %%
ebola3['Date_dt'].max() # mean()
# Out:
# Timestamp('2015-01-05 00:00:00')

# %%
ebola3['Date_dt']
# 에볼라 최초 발병일?
# 에볼라 데이터에서 최종 발병일 - 최초 발병일 = 발병 경과일
# Out:
# 0     2015-01-05
# 1     2015-01-04
# 2     2015-01-03
# 3     2015-01-02
# 4     2014-12-31
#          ...
# 117   2014-03-27
# 118   2014-03-26
# 119   2014-03-25
# 120   2014-03-24
# 121   2014-03-22
# Name: Date_dt, Length: 122, dtype: datetime64[ns]

# %%
ebola3['Date_dt'].max()-ebola3['Date_dt'].min()
# Out:
# Timedelta('289 days 00:00:00')

# %%
banks = pd.read_csv('data/banklist.csv',parse_dates=['Closing Date','Updated Date'])
banks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555 entries, 0 to 554
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bank Name              555 non-null    object
#  1   City                   555 non-null    object
#  2   ST                     555 non-null    object
#  3   CERT                   555 non-null    int64
#  4   Acquiring Institution  555 non-null    object
#  5   Closing Date           555 non-null    datetime64[ns]
#  6   Updated Date           555 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 30.5+ KB

# %%
banks = pd.read_csv('data/banklist.csv',parse_dates=[-1,-2])
banks.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555 entries, 0 to 554
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Bank Name              555 non-null    object
#  1   City                   555 non-null    object
#  2   ST                     555 non-null    object
#  3   CERT                   555 non-null    int64
#  4   Acquiring Institution  555 non-null    object
#  5   Closing Date           555 non-null    datetime64[ns]
#  6   Updated Date           555 non-null    datetime64[ns]
# dtypes: datetime64[ns](2), int64(1), object(4)
# memory usage: 30.5+ KB

# %%
banks['Closing_year'] = banks['Closing Date'].dt.year
banks['Closing_quarter'] = banks['Closing Date'].dt.quarter

# %%
banks
# Out:
#                                              Bank Name         City  ST  \
# 0                  Washington Federal Bank for Savings      Chicago  IL
# 1      The Farmers and Merchants State Bank of Argonia      Argonia  KS
# 2                                  Fayette County Bank   Saint Elmo  IL
# 3    Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI
# 4                                       First NBC Bank  New Orleans  LA
# ..                                                 ...          ...  ..
# 550                                 Superior Bank, FSB     Hinsdale  IL
# 551                                Malta National Bank        Malta  OH
# 552                    First Alliance Bank & Trust Co.   Manchester  NH
# 553                  National State Bank of Metropolis   Metropolis  IL
# 554                                   Bank of Honolulu     Honolulu  HI
#
#       CERT                Acquiring Institution Closing Date Updated Date
# ...

# %%
cyq = banks.groupby(['Closing_year', 'Closing_quarter']).size()
cy = banks.groupby(['Closing_year']).size()

# %%
cyq.plot()

# %%
cy.plot()

# %%
import pandas_datareader as pdr

# %%
# tesla = pdr.get_data_quandl("TSLA")
# tesla.to_csv('tsla.csv')

# %%
tesla = pd.read_csv('data/tesla_stock_quandl.csv',parse_dates=['Date'])
tesla.head()
# Out:
#         Date    Open    High     Low   Close      Volume  ExDividend  \
# 0 2018-03-27  304.00  304.27  277.18  279.18  13696168.0         0.0
# 1 2018-03-26  307.34  307.59  291.36  304.18   8324639.0         0.0
# 2 2018-03-23  311.25  311.61  300.45  301.54   6600538.0         0.0
# 3 2018-03-22  313.89  318.82  308.18  309.10   4914307.0         0.0
# 4 2018-03-21  310.25  322.44  310.19  316.53   5927881.0         0.0
#
#    SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume
# 0         1.0   304.00   304.27  277.18    279.18  13696168.0
# 1         1.0   307.34   307.59  291.36    304.18   8324639.0
# 2         1.0   311.25   311.61  300.45    301.54   6600538.0
# 3         1.0   313.89   318.82  308.18    309.10   4914307.0
# 4         1.0   310.25   322.44  310.19    316.53   5927881.0

# %%
tesla[tesla['Date'].dt.year==2010]
# Out:
#            Date   Open     High    Low   Close      Volume  ExDividend  \
# 1819 2010-12-31  26.57  27.2500  26.50  26.630   1417900.0         0.0
# 1820 2010-12-30  27.70  27.9000  26.38  26.500   2041100.0         0.0
# 1821 2010-12-29  27.03  28.0100  26.50  27.730   3319200.0         0.0
# 1822 2010-12-28  25.85  26.7500  25.00  26.410   4056300.0         0.0
# 1823 2010-12-27  28.02  28.5800  25.06  25.549   9301900.0         0.0
# ...         ...    ...      ...    ...     ...         ...         ...
# 1944 2010-07-06  20.00  20.0000  15.83  16.110   6866900.0         0.0
# 1945 2010-07-02  23.00  23.1000  18.71  19.200   5139800.0         0.0
# 1946 2010-07-01  25.00  25.9200  20.27  21.960   8218800.0         0.0
# 1947 2010-06-30  25.79  30.4192  23.30  23.830  17187100.0         0.0
# 1948 2010-06-29  19.00  25.0000  17.54  23.890  18766300.0         0.0
#
#       SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume
# ...

# %%
tesla_2010 = tesla.loc[tesla['Date'].dt.year==2010]
tesla_2010.loc[tesla_2010['Date'].dt.month==6]
# Out:
#            Date   Open     High    Low  Close      Volume  ExDividend  \
# 1947 2010-06-30  25.79  30.4192  23.30  23.83  17187100.0         0.0
# 1948 2010-06-29  19.00  25.0000  17.54  23.89  18766300.0         0.0
#
#       SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume
# 1947         1.0    25.79  30.4192   23.30     23.83  17187100.0
# 1948         1.0    19.00  25.0000   17.54     23.89  18766300.0

# %%
tesla.loc[(tesla['Date'].dt.year==2010) & (tesla['Date'].dt.month==6)]
# Out:
#            Date   Open     High    Low  Close      Volume  ExDividend  \
# 1947 2010-06-30  25.79  30.4192  23.30  23.83  17187100.0         0.0
# 1948 2010-06-29  19.00  25.0000  17.54  23.89  18766300.0         0.0
#
#       SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume
# 1947         1.0    25.79  30.4192   23.30     23.83  17187100.0
# 1948         1.0    19.00  25.0000   17.54     23.89  18766300.0

# %%
tesla.head()
# Out:
#         Date    Open    High     Low   Close      Volume  ExDividend  \
# 0 2018-03-27  304.00  304.27  277.18  279.18  13696168.0         0.0
# 1 2018-03-26  307.34  307.59  291.36  304.18   8324639.0         0.0
# 2 2018-03-23  311.25  311.61  300.45  301.54   6600538.0         0.0
# 3 2018-03-22  313.89  318.82  308.18  309.10   4914307.0         0.0
# 4 2018-03-21  310.25  322.44  310.19  316.53   5927881.0         0.0
#
#    SplitRatio  AdjOpen  AdjHigh  AdjLow  AdjClose   AdjVolume
# 0         1.0   304.00   304.27  277.18    279.18  13696168.0
# 1         1.0   307.34   307.59  291.36    304.18   8324639.0
# 2         1.0   311.25   311.61  300.45    301.54   6600538.0
# 3         1.0   313.89   318.82  308.18    309.10   4914307.0
# 4         1.0   310.25   322.44  310.19    316.53   5927881.0

# %%
tesla.set_index('Date')
# Out:
#               Open      High     Low   Close      Volume  ExDividend  \
# Date
# 2018-03-27  304.00  304.2700  277.18  279.18  13696168.0         0.0
# 2018-03-26  307.34  307.5900  291.36  304.18   8324639.0         0.0
# 2018-03-23  311.25  311.6100  300.45  301.54   6600538.0         0.0
# 2018-03-22  313.89  318.8200  308.18  309.10   4914307.0         0.0
# 2018-03-21  310.25  322.4400  310.19  316.53   5927881.0         0.0
# ...            ...       ...     ...     ...         ...         ...
# 2010-07-06   20.00   20.0000   15.83   16.11   6866900.0         0.0
# 2010-07-02   23.00   23.1000   18.71   19.20   5139800.0         0.0
# 2010-07-01   25.00   25.9200   20.27   21.96   8218800.0         0.0
# 2010-06-30   25.79   30.4192   23.30   23.83  17187100.0         0.0
# 2010-06-29   19.00   25.0000   17.54   23.89  18766300.0         0.0
#
#             SplitRatio  AdjOpen   AdjHigh  AdjLow  AdjClose   AdjVolume
# Date
# ...

# %%
tesla.index = tesla['Date']
tesla.index
# Out:
# DatetimeIndex(['2018-03-27', '2018-03-26', '2018-03-23', '2018-03-22',
#                '2018-03-21', '2018-03-20', '2018-03-19', '2018-03-16',
#                '2018-03-15', '2018-03-14',
#                ...
#                '2010-07-13', '2010-07-12', '2010-07-09', '2010-07-08',
#                '2010-07-07', '2010-07-06', '2010-07-02', '2010-07-01',
#                '2010-06-30', '2010-06-29'],
#               dtype='datetime64[ns]', name='Date', length=1949, freq=None)

# %%
tesla['2015'] # index가 datetime인 경우 2015인 경우가 다 나옴!!
# Out:
#                  Date    Open      High       Low    Close     Volume  \
# Date
# 2015-12-31 2015-12-31  238.51  243.4500  238.3700  240.010  2715038.0
# 2015-12-30 2015-12-30  236.60  243.6340  235.6707  238.090  3697921.0
# 2015-12-29 2015-12-29  230.06  237.7200  229.5470  237.190  2406290.0
# 2015-12-28 2015-12-28  231.49  231.9800  225.5400  228.950  1901304.0
# 2015-12-24 2015-12-24  230.56  231.8800  228.2800  230.570   710277.0
# ...               ...     ...       ...       ...      ...        ...
# 2015-01-08 2015-01-08  212.81  213.7999  210.0100  210.615  3442509.0
# 2015-01-07 2015-01-07  213.35  214.7800  209.7800  210.950  2968390.0
# 2015-01-06 2015-01-06  210.06  214.2000  204.2100  211.280  6261936.0
# 2015-01-05 2015-01-05  214.55  216.5000  207.1626  210.090  5368477.0
# 2015-01-02 2015-01-02  222.87  223.2500  213.2600  219.310  4764443.0
#
#             ExDividend  SplitRatio  AdjOpen   AdjHigh    AdjLow  AdjClose  \
# Date
# ...

# %%
tesla['refDate'] = tesla['Date']-tesla['Date'].min() # tesla 데이터의 최초일로부터 경과된 날짜가 저장
tesla
# Out:
#                  Date    Open      High     Low   Close      Volume  \
# Date
# 2018-03-27 2018-03-27  304.00  304.2700  277.18  279.18  13696168.0
# 2018-03-26 2018-03-26  307.34  307.5900  291.36  304.18   8324639.0
# 2018-03-23 2018-03-23  311.25  311.6100  300.45  301.54   6600538.0
# 2018-03-22 2018-03-22  313.89  318.8200  308.18  309.10   4914307.0
# 2018-03-21 2018-03-21  310.25  322.4400  310.19  316.53   5927881.0
# ...               ...     ...       ...     ...     ...         ...
# 2010-07-06 2010-07-06   20.00   20.0000   15.83   16.11   6866900.0
# 2010-07-02 2010-07-02   23.00   23.1000   18.71   19.20   5139800.0
# 2010-07-01 2010-07-01   25.00   25.9200   20.27   21.96   8218800.0
# 2010-06-30 2010-06-30   25.79   30.4192   23.30   23.83  17187100.0
# 2010-06-29 2010-06-29   19.00   25.0000   17.54   23.89  18766300.0
#
#             ExDividend  SplitRatio  AdjOpen   AdjHigh  AdjLow  AdjClose  \
# Date
# ...

# %%
tesla.set_index(tesla['refDate'])
# Out:
#                 Date    Open      High     Low   Close      Volume  \
# refDate
# 2828 days 2018-03-27  304.00  304.2700  277.18  279.18  13696168.0
# 2827 days 2018-03-26  307.34  307.5900  291.36  304.18   8324639.0
# 2824 days 2018-03-23  311.25  311.6100  300.45  301.54   6600538.0
# 2823 days 2018-03-22  313.89  318.8200  308.18  309.10   4914307.0
# 2822 days 2018-03-21  310.25  322.4400  310.19  316.53   5927881.0
# ...              ...     ...       ...     ...     ...         ...
# 7 days    2010-07-06   20.00   20.0000   15.83   16.11   6866900.0
# 3 days    2010-07-02   23.00   23.1000   18.71   19.20   5139800.0
# 2 days    2010-07-01   25.00   25.9200   20.27   21.96   8218800.0
# 1 days    2010-06-30   25.79   30.4192   23.30   23.83  17187100.0
# 0 days    2010-06-29   19.00   25.0000   17.54   23.89  18766300.0
#
#            ExDividend  SplitRatio  AdjOpen   AdjHigh  AdjLow  AdjClose  \
# refDate
# ...

# %%
# 거래량이 가장 많았던 날짜
tesla.iloc[tesla['Volume'].argmax()]
# Out:
# Date          2013-05-14 00:00:00
# Open                        94.22
# High                        97.12
# Low                         81.15
# Close                       83.24
# Volume                3.71639e+07
# ExDividend                      0
# SplitRatio                      1
# AdjOpen                     94.22
# AdjHigh                     97.12
# AdjLow                      81.15
# AdjClose                    83.24
# AdjVolume             3.71639e+07
# refDate        1050 days 00:00:00
# Name: 2013-05-14 00:00:00, dtype: object
